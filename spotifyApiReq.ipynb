# %%
import pandas as pd

file_path = "/Users/cheepheng/Downloads/filtered_spotify_playlists_part1.parquet"
df = pd.read_parquet(file_path)

df.head(10) # Display first few rows
# Out:
#                       name collaborative     pid modified_at  num_tracks  \
# 880377                 Gym         false  605377  2017-11-01         102
# 885166            party !!         false  332166  2017-11-01         120
# 561216               Indie         false   93216  2017-11-01         120
# 479293                 new         false  180293  2017-11-01         202
# 516040              Spooky         false  525040  2017-11-01          28
# 187139         Hip Hop/R&B         false  990139  2017-11-01          81
# 701610                AnnA         false  799610  2017-11-01         128
# 996689  white girl music !         false  635689  2017-11-01          28
# 395711               CHiLL         false  702711  2017-11-01         125
# 187106                jams         false  990106  2017-11-01         193
#
#         num_albums  num_followers  \
# 880377          89              2
# 885166         101              2
# 561216          88              1
# ...

# %%
import pandas as pd

# Load the Parquet file
df = pd.read_parquet(file_path)

# Function to extract track details from the nested tracks column
def extract_tracks(row):
    playlist_id = row["pid"]
    playlist_name = row["name"]
    
    track_list = []
    for track in row["tracks"]:
        track_list.append({
            "playlist_id": playlist_id,
            "playlist_name": playlist_name,
            "track_name": track["track_name"],
            "track_uri": track["track_uri"],
            "album_uri": track["album_uri"],
            "artist_name": track["artist_name"],
            "album_name" : track["album_name"]
        })
    
    return track_list

# Flatten all playlists into a track-level DataFrame
track_data = []
for _, row in df.iterrows():
    track_data.extend(extract_tracks(row))

# Convert to DataFrame
tracks_df = pd.DataFrame(track_data)
print(tracks_df)
# Out:
#          playlist_id playlist_name  \
# 0             605377           Gym
# 1             605377           Gym
# 2             605377           Gym
# 3             605377           Gym
# 4             605377           Gym
# ...              ...           ...
# 1226923       804606           gym
# 1226924       804606           gym
# 1226925       804606           gym
# 1226926       804606           gym
# 1226927       804606           gym
#
#                                                 track_name  \
# 0               Never Seen Runaway (Lost Soul & Genjo Mix)
# 1        Stick It out so You Can Say I Made It (Motivat...
# 2                                             Stay Schemin
# 3                                                 Just Win
# 4                                         You Be Killin Em
# ...                                                    ...
# 1226923                                    Please Don't Go
# ...

# %%
import spotipy
import os
from spotipy.oauth2 import SpotifyClientCredentials

# Replace with your credentials
SPOTIPY_CLIENT_ID = "14143fbdf78a41a99df8a9135d9e1323"
SPOTIPY_CLIENT_SECRET = "e5b815e86fb049a0afa90f2ba2583e69"

# Authenticate
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET))

#insert the URI as a string into the function
def get_album_tracks(uri_info):
    uri = []
    track = []
    duration = []
    explicit = []
    track_number = []
    one = sp.album_tracks(uri_info, limit=50, offset=0, market='US')
    df1 = pd.DataFrame(one)
    
    for i, x in df1['items'].items():
        uri.append(x['uri'])
        track.append(x['name'])
        duration.append(x['duration_ms'])
        explicit.append(x['explicit'])
        track_number.append(x['track_number'])
    
    df2 = pd.DataFrame({
    'uri':uri,
    'track':track,
    'duration_ms':duration,
    'explicit':explicit,
    'track_number':track_number})
    
    return df2

# %%
import spotipy
import os
from spotipy.oauth2 import SpotifyClientCredentials


# Replace with your credentials
SPOTIPY_CLIENT_ID = 
SPOTIPY_CLIENT_SECRET = 

# Authenticate
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET))

def get_track_details(track_uri, album_uri):

    track_info = sp.track(track_uri)
    album_info = sp.album(album_uri)

    return {
        "track_name": track_info["name"],
        "track_popularity": track_info["popularity"],
        "album_name": album_info["name"],
        "album_release_date": album_info["release_date"],
    }


track_metadata = []
for _, row in tracks_df.head().iterrows():
    track_info = get_track_details(row["track_uri"], row["album_uri"])
    if track_info:
        track_metadata.append(track_info)

# Convert API results to DataFrame
track_metadata_df = pd.DataFrame(track_metadata)

print(track_metadata_df)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 77016

# %%
# #insert the URI as a string into the function
# def get_album_tracks(uri_info):
#     uri = []
#     track = []
#     duration = []
#     explicit = []
#     track_number = []
#     one = sp.album_tracks(uri_info, limit=50, offset=0, market='US')
#     df1 = pd.DataFrame(one)
    
#     for i, x in df1['items'].items():
#         uri.append(x['uri'])
#         track.append(x['name'])
#         duration.append(x['duration_ms'])
#         explicit.append(x['explicit'])
#         track_number.append(x['track_number'])
    
#     df2 = pd.DataFrame({
#     'uri':uri,
#     'track':track,
#     'duration_ms':duration,
#     'explicit':explicit,
#     'track_number':track_number})
    
#     return df2

# %%
# def get_track_info(df):
#     danceability = []
#     energy = []
#     key = []
#     loudness = []
#     speechiness = []
#     acousticness = []
#     instrumentalness = []
#     liveness = []
#     valence = []
#     tempo = []
#     for i in df['uri']:
#         for x in sp.audio_features(tracks=[i]):
#             danceability.append(x['danceability'])
#             energy.append(x['energy'])
#             key.append(x['key'])
#             loudness.append(x['loudness'])
#             speechiness.append(x['speechiness'])
#             acousticness.append(x['acousticness'])
#             instrumentalness.append(x['instrumentalness'])
#             liveness.append(x['liveness'])
#             valence.append(x['valence'])
#             tempo.append(x['tempo'])
            
#     df2 = pd.DataFrame({
#     'danceability':danceability,
#     'energy':energy,
#     'key':key,
#     'loudness':loudness,
#     'speechiness':speechiness,
#     'acousticness':acousticness,
#     'instrumentalness':instrumentalness,
#     'liveness':liveness,
#     'valence':valence,
#     'tempo':tempo})
    
#     return df2

# %%
# import spotipy
# import os
# from spotipy.oauth2 import SpotifyClientCredentials


# # Replace with your credentials
# SPOTIPY_CLIENT_ID = "14143fbdf78a41a99df8a9135d9e1323"
# SPOTIPY_CLIENT_SECRET = "e5b815e86fb049a0afa90f2ba2583e69"

# # Authenticate
# sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
#     client_id=SPOTIPY_CLIENT_ID,
#     client_secret=SPOTIPY_CLIENT_SECRET))

# def get_track_details(track_uri, album_uri):
#     try:
#         track_info = sp.track(track_uri)
#         album_info = sp.album(album_uri)

#         return {
#             "track_name": track_info["name"],
#             "track_popularity": track_info["popularity"],
#             "track_duration_ms": track_info["duration_ms"],
#             "album_name": album_info["name"],
#             "album_release_date": album_info["release_date"],
#             "album_total_tracks": album_info["total_tracks"],
#             "artist_name": track_info["artists"][0]["name"]
#         }
    
#     except Exception as e:
#         print(f"Error fetching data for {track_uri}: {e}")
#         return None

# track_metadata = []
# for _, row in tracks_df.head().iterrows():
#     track_info = get_track_details(row["track_uri"], row["album_uri"])
#     if track_info:
#         track_metadata.append(track_info)

# # Convert API results to DataFrame
# track_metadata_df = pd.DataFrame(track_metadata)

# print(track_metadata_df)
