# %% [markdown]
# Extract Preview URL

# %%
import subprocess
import json
import time
import pandas as pd
import math
import os
import re
import glob

def get_spotify_previews_batch(df_batch):
    data_json = df_batch.to_json(orient="records")
    result = subprocess.run(
        ["node", "spotify_preview.js"],
        input=data_json,
        stdout=subprocess.PIPE,   # Capture stdout explicitly
        stderr=subprocess.STDOUT,  # Merge stderr into stdout
        text=True,
        encoding='utf-8'
    )
    
    # Print all output so any warnings or messages are visible
    print(result.stdout)
    
    try:
        return json.loads(result.stdout)
    except json.JSONDecodeError:
        raise ValueError(f"Invalid JSON output: {result.stdout}")

def get_last_processed_batch(directory):
    """Find the last batch number from saved CSV files in the specified directory."""
    if not os.path.exists(directory):
        os.makedirs(directory)
        return 0  # No batches processed yet

    batch_files = [f for f in os.listdir(directory) if f.startswith("batch_") and f.endswith(".csv")]
    batch_numbers = []
    for filename in batch_files:
        match = re.search(r"batch_(\d+)\.csv", filename)
        if match:
            batch_numbers.append(int(match.group(1)))
    return max(batch_numbers, default=0)  # Return the last processed batch number

def get_new_merged_filepath(directory, base_name='merged_file.csv'):
    """
    Return a file path for the merged file. If a file with the base name already exists,
    append a number to avoid overwriting.
    """
    merged_filepath = os.path.join(directory, base_name)
    if not os.path.exists(merged_filepath):
        return merged_filepath
    else:
        i = 1
        new_name = f"merged_file({i}).csv"
        new_filepath = os.path.join(directory, new_name)
        while os.path.exists(new_filepath):
            i += 1
            new_name = f"merged_file({i}).csv"
            new_filepath = os.path.join(directory, new_name)
        return new_filepath

def merge_preview_batches(directory):
    """
    Merge all CSV files from the given directory (which holds preview batch CSVs),
    drop duplicates by 'track_uri' while prioritizing those with valid 'previewUrl',
    save the merged DataFrame (using a new filename if a merged file already exists),
    and delete all individual batch CSV files.
    """
    csv_files = glob.glob(os.path.join(directory, '*.csv'))
    if not csv_files:
        print(f"No CSV files found in {directory}.")
        return pd.DataFrame()
    
    dfs = [pd.read_csv(file) for file in csv_files]
    previews = pd.concat(dfs, ignore_index=True)
    # Sort so that rows with non-NaN previewUrl come first,
    # then drop duplicates by 'track_uri' keeping the first occurrence.
    previews = previews.sort_values(by=['previewUrl'], ascending=False)\
                       .drop_duplicates(subset=['track_uri'], keep='first')
    
    merged_filepath = get_new_merged_filepath(directory)
    previews.to_csv(merged_filepath, index=False)
    print(f"Merged file saved to {merged_filepath}")
    
    # Delete individual batch CSV files (but not any previously merged files)
    batch_files = glob.glob(os.path.join(directory, 'batch_*.csv'))
    for file in batch_files:
        try:
            os.remove(file)
            print(f"Deleted {file}")
        except Exception as e:
            print(f"Could not delete {file}: {e}")
    return previews

def get_spotify_previews_in_batches(dataframe, batch_size=50, delay=2, output_dir=""):
    # Use current working directory if output_dir is empty
    if not output_dir:
        output_dir = os.getcwd()

    last_batch = get_last_processed_batch(output_dir)
    print(f"Resuming from batch {last_batch + 1} in directory: {output_dir}...")

    # Skip already processed batches based on batch count
    dataframe = dataframe.iloc[last_batch * batch_size:]
    num_songs = len(dataframe)
    total_batches = math.ceil(num_songs / batch_size)

    for i in range(0, num_songs, batch_size):
        batch_df = dataframe.iloc[i:i+batch_size]
        batch_index = last_batch + (i // batch_size) + 1
        print(f"Processing batch {batch_index} of {total_batches + last_batch}...")
        
        batch_results = get_spotify_previews_batch(batch_df)
        batch_data = []
        
        for entry in batch_results:
            if entry is None:
                continue
            track_name = entry.get("track_name")
            track_uri = entry.get("track_uri")
            preview_url = None
            if "error" not in entry or not entry.get("error"):
                preview_urls = entry.get("previewUrls", [])
                preview_url = preview_urls[0] if preview_urls else None
            batch_data.append({
                "track_name": track_name,
                "track_uri": track_uri,
                "previewUrl": preview_url
            })
        
        batch_df_results = pd.DataFrame(batch_data)
        csv_filename = f"batch_{batch_index}.csv"
        batch_filepath = os.path.join(output_dir, csv_filename)
        batch_df_results.to_csv(batch_filepath, index=False)
        print(f"Batch saved to {batch_filepath}")

        if i + batch_size < num_songs:
            time.sleep(delay)

if __name__ == "__main__":
    # Ask user for the directory where batch CSVs are saved.
    output_dir = input("Enter the directory where batch CSVs are saved (default: current working directory): ").strip()
    if not output_dir:
        output_dir = os.getcwd()
    
    # Folder containing the preview batch CSV files.
    preview_batches_dir = "preview_batches_Xav"
    
    # Merge any existing preview batch CSV files and clean up batch files.
    merged_previews = merge_preview_batches(preview_batches_dir)
    
    # Load the full tracks dataset (adjust path if needed)
    df = pd.read_parquet('../../parquet datasets/tracks_XavierHua.parquet')
    df = df[['track_name', 'track_uri']]
    
    # If there is a merged file, skip tracks that already have a valid previewUrl.
    if not merged_previews.empty:
        processed_track_uris = merged_previews[~merged_previews['previewUrl'].isna()]['track_uri'].unique()
        df_to_process = df[~df['track_uri'].isin(processed_track_uris)]
        print(f"Found {len(processed_track_uris)} processed tracks. {len(df_to_process)} tracks remain to be processed.")
    else:
        df_to_process = df
        print("No previously processed tracks found, processing all tracks.")
    
    # Process the remaining tracks in batches (by default 50 per batch)
    get_spotify_previews_in_batches(df_to_process, output_dir=output_dir)
    merge_preview_batches(preview_batches_dir)
# Out:
# Merged file saved to preview_batches_Xav/merged_file(2).csv
# Deleted preview_batches_Xav/batch_1.csv
# Deleted preview_batches_Xav/batch_2.csv
# Deleted preview_batches_Xav/batch_3.csv
# Deleted preview_batches_Xav/batch_4.csv
# Deleted preview_batches_Xav/batch_5.csv
# Found 48550 processed tracks. 1897 tracks remain to be processed.
# Resuming from batch 1 in directory: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav...
# Processing batch 1 of 38...
# [{"track_name":"What I Might Do - Kilter Remix","track_uri":"spotify:track:6codEgrEs41B6j01nkSIqe","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Post Malates","track_uri":"spotify:track:7wLB0OVFKakmbkUFmh9C58","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lovin U (feat. Xiomara)","track_uri":"spotify:track:2YCkPwsWHsTPSTgEwqhxQl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Somewhere In My Car","track_uri":"spotify:track:3MFV4DgrAOXz6KURPQxRj9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Set Me On - David August Remix","track_uri":"spotify:track:2F8MgAU5ZQ2Io6lpNoL9rm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Last Train (Helmut Dubnitzky Remix)","track_uri":"spotify:track:3xUKI0DuBAeb9QqG6gjBvf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Outcast - Life on Planets Edited Acoustic Version","track_uri":"spotify:track:6y2fftJ4JRRV7do75wNhVn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"On The Streets - Kollectiv Turmstrasse Let Freedom Ring Remix","track_uri":"spotify:track:3dIDlK8DT2mVKh4syOTzd6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tipsy Ballad - Original Mix","track_uri":"spotify:track:3J2OatbDaGXNt8jyU76zwd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Neon - EP Version","track_uri":"spotify:track:25ueyWzih8QBtf7EzHc3aW","previewUrls":[],"error":"No preview URLs found"},{"track_name":"No One's Gonna Love You - Live Acoustic","track_uri":"spotify:track:2eoVXXCe2Uryug9QiXH0RI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Break Bones - Duet","track_uri":"spotify:track:6MZDu8KOgbhwSBG5NACxf9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rolling Dice","track_uri":"spotify:track:6WajsNz9LLdhxIxfnhN2jC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sounds Of Her Mind","track_uri":"spotify:track:3HivSIXzkrz9d6k4kGwHCU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Spooky Scary Skeletons","track_uri":"spotify:track:1uwoFw5pikBHlTWMRedaLx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hypnotized","track_uri":"spotify:track:6fXzclKMWcYFIvRPREufPf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sexy Can I","track_uri":"spotify:track:78c3IFOZdqCvelTH65zA0g","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wetter (Calling You Daddy)","track_uri":"spotify:track:0gPPfRl1qmyEuWQJVD2EW0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Jubel","track_uri":"spotify:track:03RENvqJKYdvWUhbuZwJY3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Familiar Footsteps","track_uri":"spotify:track:37bXUP2iDLnRPe7Nryg6jZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love On A Two-Way Street","track_uri":"spotify:track:0jiRuwY4M0akGkEYbRiI6U","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rocky Raccoon","track_uri":"spotify:track:1mfx1lu0RmoRkkPqo6Y7aa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Champagne","track_uri":"spotify:track:6cZC4pSjcJUAeBRq1xgonl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rebound (feat. Emily Weisband)","track_uri":"spotify:track:2T9QCRiYah7FTX25XebmWm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Make That Move","track_uri":"spotify:track:7vPd1EHjkZGXdHVwf9fXVd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hold My Beer","track_uri":"spotify:track:7bLREO1LT5XtqTKU85xyxm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ala-Freakin-Bama","track_uri":"spotify:track:63puNJX3U2WTPNexLnFQ4p","previewUrls":[],"error":"No preview URLs found"},{"track_name":"If That Ain't Country","track_uri":"spotify:track:0vmtIKcJSsphwR6MLWF5Uz","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Flex","track_uri":"spotify:track:2K84U6t61piAv8X1VmDEae" ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_1.csv
# Processing batch 2 of 38...
# [{"track_name":"C.O.P Criminals of Permision","track_uri":"spotify:track:4lXR0LQGv4d7ucR8joiNxj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm Crazy","track_uri":"spotify:track:02oCyqbuFnHRbb17bYdrsO","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Love My Niggas","track_uri":"spotify:track:0qW03aEjEk8BaWXbXb5KcJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hat of Rain","track_uri":"spotify:track:28bvyDj3R9pNU96f7hTF2W","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Blessed","track_uri":"spotify:track:2V28RKTOabMKk2xvIDyCEz","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cold Water (feat. Justin Bieber & MØ) - Lost Frequencies Remix","track_uri":"spotify:track:3LHY5vSKZzxLy3Cog0aG5B","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Something Good - Acoustic Version [Live From Spotify NYC]","track_uri":"spotify:track:4Yr5SL7tfeRMAGkum5WzoY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Can't Make You Love Me/Nick of Time","track_uri":"spotify:track:76NHoWRJrfjx0rtF6OZRsM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Come, Thou Fount Of Every Blessing (복의 근원 강림하사)","track_uri":"spotify:track:6EcstKKunGdhOJFI5FLXrw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Wanna Dance With Somebody","track_uri":"spotify:track:4jc1lf0rejPuA8t6LBACfw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Homesick and Hotelrooms","track_uri":"spotify:track:4DbXO5KJ3hUzyVakbUp3rh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm in Love With You","track_uri":"spotify:track:4GTT9nJKpMniMHvw8Q5SrH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Nimm dir Zeit","track_uri":"spotify:track:6vBDMCpbmnoek96xUTyQGu","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Look at Me!","track_uri":"spotify:track:2oUuLLKS8WbF7ELJcwbqms","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Run This Town","track_uri":"spotify:track:15htJ7MpJFsmS23taoCmSn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Backseat Flip","track_uri":"spotify:track:17LoaQwCec9YqJzdr0jycO","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm on a Roll (feat. New Boyz & Rock Mafia)","track_uri":"spotify:track:7qjZjMEPBc89mv4rDzGrh4","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Paradise Loft","track_uri":"spotify:track:2DdtMAxKKUAfbqyPR0TW5m","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Toast","track_uri":"spotify:track:53J8qqIsdfjpwDLKdy6oQj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Dirty Little Secret - Thievery Corporation Mix","track_uri":"spotify:track:0inFPTTNaGMOQjRv67Xi78","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Knock You Out - Owen Westlake Remix","track_uri":"spotify:track:2eU9HaCt0Vgz0XfpU6M7QU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Here For You - Bronze Whale Remix","track_uri":"spotify:track:0VHQXDkqsnd5JsjFz6vBGV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Earthquake - Original Mix","track_uri":"spotify:track:5lbjCJfyGl0fjoaTUVRZxF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ordinary Lies (feat. Bella Musser) (Hudson Lee & Clockvice Remix","track_uri":"spotify:track:5eQFeZswHIdHl0AQvKcfEM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ukiyo","track_uri":"spotify:track:3nKx86fcs8MYMydill0Sya","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Slow Emotion - Original Mix","track_uri":"spotify:track:0NUArejLh04xSVgBWaMY8V","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Run - Illenium & Said The Sky Remix","track_uri":"spotify:track:7IOPTgzKSvLcsfZPooE0If","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Acid Love","track_uri":"spotify:track:0YuLjgPEbTjREhBnvpf8qT","previewUrl ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_2.csv
# Processing batch 3 of 38...
# [{"track_name":"자니 (feat. Dynamicduo)","track_uri":"spotify:track:5qQeKwoqmnc9qAvXjBKITg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"친구로 남아줄께","track_uri":"spotify:track:6DzXeZWEgydnoquttYoRJg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"All of Me","track_uri":"spotify:track:4fi1zSHFjyDM8TpUWLodsL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Runaway","track_uri":"spotify:track:49QrJBMxYZA5nAgqbqBpca","previewUrls":[],"error":"No preview URLs found"},{"track_name":"New Recording 135","track_uri":"spotify:track:5XnDrJU5kv4EmgiTfgLmyo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wonderful World","track_uri":"spotify:track:45Wpgtsrfej6Ny6XNzcS7G","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Snakes","track_uri":"spotify:track:3ikt9XOTnVFT56RKJF7cot","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Blast","track_uri":"spotify:track:7qMflhMLIirt85pzo1xo6X","previewUrls":[],"error":"No preview URLs found"},{"track_name":"In My Yard (I Don't Know)","track_uri":"spotify:track:1YjzzI3WSq2pXjNkbwf4Sw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Young (feat. Una Mey)","track_uri":"spotify:track:34uTrBYdIGZV9gjUkS7I0H","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Last","track_uri":"spotify:track:5flE7KIMjNHJRlEy6N2L5D","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Louder","track_uri":"spotify:track:59uwTlMNsbZExng4OZ13KE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Fuck It","track_uri":"spotify:track:3aQ2KWZB5gTd1MrPyULpKa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stay Woke","track_uri":"spotify:track:6C9F7S9BzGidq9QAdqPoNm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sam Tabaat Aleha","track_uri":"spotify:track:3Lfnd2JWZNWdNpJ3BXXQPA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hagiga BeIsrael","track_uri":"spotify:track:6ditsG6XarazLiEDYsoQz2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Katzefet Im Tut - Himnon Hagaava Shel Evita","track_uri":"spotify:track:2vStK2YsETYRr4614lRzQJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mashup Lehitey 2016","track_uri":"spotify:track:4DunrIoRgVz4bs9FbR90W7","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mazal Mozanaim","track_uri":"spotify:track:1zlf8x8dOEKwO5uo5CvcK9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Kol Habanot","track_uri":"spotify:track:0RArGwu8vt5cSPHCZPoEPv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Watching The Wheels - 2010 - Remaster","track_uri":"spotify:track:4NjyI3qjCRv3XZXgcISc8E","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rubbin Off the Paint","track_uri":"spotify:track:0Y6oJgkRrRIEkaishGUssS","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rubbin off the Paint","track_uri":"spotify:track:6rZFgf3CfLfjDrm10bbfrR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"We Might Fall","track_uri":"spotify:track:3KrnkTF84wu0KF3vqVYgEh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Lied","track_uri":"spotify:track:5btqzCB1tRbgcw1SJhrdzv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cold Beer With Your Name On It","track_uri":"spotify:track:0O1CQfWx3Q1Z3o8U4JSE6P","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Reckless","track_uri":"spotify:track:72UoNION8BUCUXlHhWw5AH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mundian To Bach Ke - Radio Mix","track_uri":"spotify:track:53k2QxBbl3hTxpvIDTLumv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Put On Your Sunday Clothes - 1969 Soundtrack Recording","track_uri":"spotify:track:57FpTIggnivNM59R2lYiXG","previewUrls":[],"error":"No preview URLs found"},{"track_name":"BNL","track_uri":"spotify:track:1X2uLMtCTEAWdMxL7MiTkq","previ ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_3.csv
# Processing batch 4 of 38...
# [{"track_name":"Icarus","track_uri":"spotify:track:7BiAsId2JTF6saW28t6Ent","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Clumsy","track_uri":"spotify:track:4Q1PVjSD9PfK5GSWJvn5X0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Borkian Dervish, Thomas de Hartmann & Gi Gurdjieff","track_uri":"spotify:track:6HZO7JAFOP0JOoYsmuGGXB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stardust (Forever Young)","track_uri":"spotify:track:1ebRu39LEFf6nsHjdLREAo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"So Good to Me - Radio Edit","track_uri":"spotify:track:3fDrZa4ksxA5lgi0utGu6k","previewUrls":[],"error":"No preview URLs found"},{"track_name":"#3Way - Intro","track_uri":"spotify:track:5jlPadTNwjyUOKEiSwuFQb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Where They At","track_uri":"spotify:track:6s9MuZrXLDC9jp0S2d0YC6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Worse It Gets (RAC Mix)","track_uri":"spotify:track:3frk9g3FM8ZJZdEj7Zv9j6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sober Thoughts","track_uri":"spotify:track:73q3N53lF5wEOwQja56tiC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You Lied","track_uri":"spotify:track:5ec9KeSKipgdRvQC7hc7f6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Life Is Short","track_uri":"spotify:track:7t2eWdGWBTAxaXxaGqq9ts","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Victim","track_uri":"spotify:track:3eS0XnF1EK5a0xMr8cUdrX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Seven Nation Army","track_uri":"spotify:track:2s9UHFkFHGX62U5WVlAmv8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Shattered","track_uri":"spotify:track:2RRaCs3xr1SWmrUZfPqIVM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Take Me There","track_uri":"spotify:track:1wxVcS1qqIK0fjxDd8rIeo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Deception","track_uri":"spotify:track:0joBFVeVFS1YaPXHKVJ3n9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hostage","track_uri":"spotify:track:7L9b4DcYOqUMsryjTPzKGH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tell Me What You're Made Of - Radio Edit","track_uri":"spotify:track:2taOLlRnaFgVm9o0F56N1f","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Machine","track_uri":"spotify:track:0gHq4usJ0eAxS1q7b6IRY3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Blow Out","track_uri":"spotify:track:6p9tnJiOxS7TEOhjbbsyPv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Take Control of Me","track_uri":"spotify:track:5Fsgpqzyr9gNayfnia7fhN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"It Takes A Muscle [To Fall In Love]","track_uri":"spotify:track:6Pso6GvWOxy42HVA4bsF0o","previewUrls":[],"error":"No preview URLs found"},{"track_name":"For All the Times...","track_uri":"spotify:track:1cZtzrRGyYTJPGRmLubrep","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You Can Go","track_uri":"spotify:track:40uwa5pF5CyN4hR4t9lZo2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Welcome Chris","track_uri":"spotify:track:4zEqFyNLXFu7wwnsEvYVJ6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Godfather","track_uri":"spotify:track:1oTcZDFNXbbRHKxHSuuQ5d","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ameno","track_uri":"spotify:track:5K344lrmS5xDkA1NPR93mw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hold My Hand - Feenixpawl Remix","track_uri":"spotify:track:1af8aYyNmtlMesXVs4UaLd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Real Love - The Chainsmokers Remix","track_uri":"spotify:track:3a0RuyCRfeZwly3mom48nP","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bad Intentions","track_uri":"spotify:track:5uikGLo0VR0LfqxMQAYxnx", ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_4.csv
# Processing batch 5 of 38...
# [{"track_name":"Head Huncho","track_uri":"spotify:track:5GY2cYxvWXd7fYZm1TBfG2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"El Negrito","track_uri":"spotify:track:1wYwIRmbVAhhiQHflZKN69","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Burrito Mix","track_uri":"spotify:track:2bQ1boWaChcKgmOwhd3wMq","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Solar Flare","track_uri":"spotify:track:5SL5xhZg3Ee801gc34QsI1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"G I R L","track_uri":"spotify:track:21WXkdljwf9Y4PUa3tl7D7","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Heart Afire","track_uri":"spotify:track:0JQjr0kpluPAuskMPHjqh3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Terryfold","track_uri":"spotify:track:29tzM8oIgOxBr3cI9CBOpb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Trouble On My Mind","track_uri":"spotify:track:4IEStF1H3zbSPTV2GS5OSs","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Amazing Amy","track_uri":"spotify:track:0sAh9V9Wn6C7mQ5nhPsEkb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Rainbow","track_uri":"spotify:track:3x5FrVKxTEOAYGaVPDMgMU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Take Over Control - US Radio Edit","track_uri":"spotify:track:449TKY3KrO135SN8hyT2kp","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Decide","track_uri":"spotify:track:0LyMc2zwSPsp955GPVvELd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"TALK","track_uri":"spotify:track:7tymagtf8toMHFuZXBPYfE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lost In The Sound","track_uri":"spotify:track:1BYybvdKrH7A4fFZeyjf69","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Home Alone","track_uri":"spotify:track:01GElUuJToDk1R7onJpH2Q","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Back On The Wall","track_uri":"spotify:track:4FSRYCh5AQ7TEsYqba8xSW","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pretty Hurts","track_uri":"spotify:track:1Eu0oPXFOVzQr0MSTULJD6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Reaching Out","track_uri":"spotify:track:4zmf7uN2pK5czcRKVhrJxi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Romances","track_uri":"spotify:track:1RiKbwqb2O03JT7Bu3dIr2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The First Steps","track_uri":"spotify:track:5Ica7TWlqa11k4R4VBR2aR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"With Love","track_uri":"spotify:track:0siURtUu2AkRV692VUhBkS","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Safety Dance (Video Version) - Bonus Track","track_uri":"spotify:track:41MOCUNOgWtaYBFUsGnpZ5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Me, Myself & I","track_uri":"spotify:track:7ao6UmSKAz3kponATY1qRW","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hot Nigga","track_uri":"spotify:track:2bwGzRqbELz8gknTMCchoY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Think I Like You","track_uri":"spotify:track:0j832FR4bqJ1vtAb2JDD7H","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love Hate Relationship","track_uri":"spotify:track:74t8ZSV8l9ifqSVZGLyMTv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Living in the Eye of the Storm","track_uri":"spotify:track:2xlNFJtpBkXQJpCfaZZkKL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Too Close","track_uri":"spotify:track:6PmKXRG7p1MW86kJMZb0pR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Finally Free","track_uri":"spotify:track:65OI98eONiwLbJjVeCihI3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bounce Rock Skate Roll","track_uri":"spotify:track:0nwLY7Iwgu97Hstdz3bOjZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"It Takes Two ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_5.csv
# Processing batch 6 of 38...
# [{"track_name":"Robert E. Lee","track_uri":"spotify:track:2tKMnOSFx9dsjoykoHnGVH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pennsylvania Avenue","track_uri":"spotify:track:4bmFmRdQYyzGCSVIW9uhu3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Back In the USA","track_uri":"spotify:track:6aCLkhrp7SmdfQohGMGti4","previewUrls":[],"error":"No preview URLs found"},{"track_name":"La County Blues","track_uri":"spotify:track:6YQqilJQTaUBJZ5rPDGvw6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lost & Found","track_uri":"spotify:track:7ui7CeeUVhKEtjElhcDoAl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Time to Switch to Whiskey","track_uri":"spotify:track:0RuuI3sCJIPfnR0iFr3hMH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Skyline Radio","track_uri":"spotify:track:66JtCfxb3QxWANVskO4EtA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sympathy For A Train","track_uri":"spotify:track:5tujLKi5zeKImX2yOnHLSQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Victory Bells","track_uri":"spotify:track:7Douu0YWebbhJU7qWWUY1O","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Good One Coming On","track_uri":"spotify:track:4znq6wqSKy5YdEt98d8z13","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Rose Hotel","track_uri":"spotify:track:1MMlqO11yahy97aDtYjiBh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"It Wasn't Me","track_uri":"spotify:track:6276XQhjrrOD3bW5EaLQNz","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Vibrations","track_uri":"spotify:track:5qGsaVUKTULC0j0fZcXtVh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cosmic Angel - Acoustic From Capitol Studios","track_uri":"spotify:track:5RVuBrXVLptAEbGJdSDzL5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love Rollercoaster","track_uri":"spotify:track:2VW3Mcwjgs4NO4P6kx52C0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Dream","track_uri":"spotify:track:4bm5sh12yDPEJkWbO27pDw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm Not Gonna Teach Your Boyfriend How to Dance with You - The Twelves Remix","track_uri":"spotify:track:05YARn3kzTUHA5apOUZVIQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cape Town - Panama Remix","track_uri":"spotify:track:0PB59W8aC4UodGSf4GmG5x","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Y.W.M.O. - Extended Mix","track_uri":"spotify:track:14p7iZcDus7lxW4qQfm7GU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"This Disorder","track_uri":"spotify:track:3Tny13Wy19lH3octgSKMv3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Shame - That's Nice Remix","track_uri":"spotify:track:18fuOuE3rTBwH4WzCGdwrO","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Kiss","track_uri":"spotify:track:75DVxUvsGVs2Sehv2o4fMc","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tears For Animals","track_uri":"spotify:track:2kH9pYAE74wdKG80AtL73q","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love Me Tender","track_uri":"spotify:track:7CR0AgPCTmwKrg8hrtTJVV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Won't Give Up (Live)","track_uri":"spotify:track:3S9FJKxCKWnR5CTd5seCMQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Last of the Wildcards","track_uri":"spotify:track:6lV8Gi8VFOjMDw3yj1CcBQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Fly High 2K17 - Klubjumpers Remix","track_uri":"spotify:track:363t6WHWL87s3QsVypQ2ey","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Place of Freedom","track_uri":"spotify:track:0H9g5Ozxy8rfFP02owRFwD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Real Love - Studio Version","track_uri":"spotify:track:0epQ2DrozCuhE2Q7ZRtF2h","previewUrls":[],"error":"No preview URLs found ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_6.csv
# Processing batch 7 of 38...
# [{"track_name":"The Second Time Around","track_uri":"spotify:track:6s0X1Gr7YLsJanEL22s93G","previewUrls":[],"error":"No preview URLs found"},{"track_name":"A Night to Remember","track_uri":"spotify:track:2xsXNMfcKLQxL5sQq4v7gH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"This Is for the Lover in You","track_uri":"spotify:track:2S71OY6sxbyOqYUszSJW9b","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You're My Latest, Greatest Inspiration","track_uri":"spotify:track:24Uu2LvYtrQucgUL69WzMx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lost Love (feat. Biggie Bk)","track_uri":"spotify:track:4J1HVttweZ18aI1eniQ7x0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Chill Bill","track_uri":"spotify:track:05oQLi2pLjDzBtNzOG5zGC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lil Peep","track_uri":"spotify:track:4JeInPm5aNC7iOuMixaY9t","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lil Dicky Desiigner Cypher","track_uri":"spotify:track:1o7yU3BgnOELzqBpvglxGX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tears","track_uri":"spotify:track:1YzN3Q9gfF9LsGikr5zvw3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lost You","track_uri":"spotify:track:6Rjk8HQZz8l4zH7fr0o7AE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Turbulence","track_uri":"spotify:track:1516vNsRKpRnUf5DguGL5I","previewUrls":[],"error":"No preview URLs found"},{"track_name":"2 Step (feat. T-Pain, Jim Jones & E-40)","track_uri":"spotify:track:34vVztCAeKpPtzYfGHQjiV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Copper and Robbers","track_uri":"spotify:track:0MQ6TxR0zsFHjMrhEt5lIk","previewUrls":[],"error":"No preview URLs found"},{"track_name":"3 Way","track_uri":"spotify:track:1d96GSayjrsy5A1TuTCrZA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Coupon","track_uri":"spotify:track:1lRNzCfeOWPyvLo4m8ss9q","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stronger ft Quavo (Migos Edition)","track_uri":"spotify:track:521VYnU7ZK3RINIdOwd8OY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ghetto Superstar","track_uri":"spotify:track:34SGS44o6ikNS9jpWLFH14","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pu$$y","track_uri":"spotify:track:54ohgeZ4ESJDlffKb9Ktrt","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Xhampagne (feat. Antwon)","track_uri":"spotify:track:70aGNEZzj831Htgfcpqrpq","previewUrls":[],"error":"No preview URLs found"},{"track_name":"2 Door","track_uri":"spotify:track:1E2pJZOSzzNRYBonCWmDlB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lord Vader Kush II","track_uri":"spotify:track:0cYXDYsQalD3SeLuI5f1J6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Black Mass","track_uri":"spotify:track:157JUKrdDgeijvPGNxSziq","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Hooch","track_uri":"spotify:track:0Hh4BtHHtmPnG6q0KGMEgw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"D.O.A.","track_uri":"spotify:track:1Y4Vwcr9XW7kdbvUvPawPf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'll Keep Loving You","track_uri":"spotify:track:0iR3mTJ5om6Pv9Boo50dch","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Intoxicated","track_uri":"spotify:track:3XOVVeBq4PysEunStKbjon","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pompeii","track_uri":"spotify:track:0yPiCq3SmMQwXFZdRgUQTJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Home (RAC Mix)","track_uri":"spotify:track:6Zzz76FHcVbxs90KmBlvW3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mary Jane","track_uri":"spotify:track:6WIrz9Aw4PVQYNh5vrAZB3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Digital Girl","track_uri":"spotify:track:5DeHBI8yu2Of8jpz431auo","previewUrls":[],"error":"No preview URL ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_7.csv
# Processing batch 8 of 38...
# [{"track_name":"Panda - IVY Remix","track_uri":"spotify:track:4QU4yTWATuYAOd025b4H4P","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hitman","track_uri":"spotify:track:6L4MeZzr2bbgnouXmlIgSo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Feel Me","track_uri":"spotify:track:2Cth0v1xri32oZ799rL3rl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bad Influence","track_uri":"spotify:track:2qsu72iORi3GYqVarujJZn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Not Right Now","track_uri":"spotify:track:5rpcMlx7zXaaFkiHYW1rkL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stars in the Ceiling","track_uri":"spotify:track:5ZfHOOLXT9gFfGdVFGs3eV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stupid ft PnB Rock","track_uri":"spotify:track:7Ms921kIKGLo8TXUPzO43G","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Feelin Blessed","track_uri":"spotify:track:2BYCPk9lN0KOl4p3GgKhkj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Look Back at It (feat. Slim Jenkinz)","track_uri":"spotify:track:7FeEA2XfmSOU1D63MHXAGD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Waiting (feat. LANDON)","track_uri":"spotify:track:1G6etLyLMOl2m5ghHxat2J","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Let Me Take You Out","track_uri":"spotify:track:4tM7IvirymOPAk74Us27kD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"CHA CHA","track_uri":"spotify:track:44Xgp13T5ab99beJ0edP6b","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Barlow Knife","track_uri":"spotify:track:3bh0m7hoROKgLfl9fAlIvZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"March Madness","track_uri":"spotify:track:26oF6WjkOjDIRK9YsdZp2l","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hello","track_uri":"spotify:track:193O4vZOZvdx7vrfZpfs37","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Leave Your Boyfriends Behind","track_uri":"spotify:track:2v350fZfyAOjelugBlHgdd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Heavy Like Sunday","track_uri":"spotify:track:0MQ17RYP6JNnMT2u2aPuh8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"With You in My Head (feat. The Black Angels)","track_uri":"spotify:track:2o5HusR6pQjjf5qXR86p5O","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Not So Different At All","track_uri":"spotify:track:7yRxjUoDw9sYReplkHNqlx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Wanna Know You","track_uri":"spotify:track:7FEwZ6YpzrzB3tYr9jtfL7","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Drip on Me","track_uri":"spotify:track:2ya9d4B06EQ8Fpj5SSqiTH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pursuit of Happiness","track_uri":"spotify:track:3N82TYrLNCm71b3t0h1LLB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Geronimo's Cadillac","track_uri":"spotify:track:6ikQQmkMEb5HYKXUhozRX8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Shaky Shaky Fitness Music Moombahton Bootleg","track_uri":"spotify:track:7FkzfNXjwfaPNjN5MnApub","previewUrls":[],"error":"No preview URLs found"},{"track_name":"La Dueña del Swing","track_uri":"spotify:track:3vCeDhrInX8te6SoaqZbvu","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Live At Jimmys (La Gran Manzana)","track_uri":"spotify:track:1864UhhWhfNq8Ne59zOa7h","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Guantanamera","track_uri":"spotify:track:4yQp99N7Rk5FFwL7JdpiS3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Choice Is Yours","track_uri":"spotify:track:6281LdA2cVFwVM0xC5cqA8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Message - 12\" Single Version","track_uri":"spotify:track:1TVdsmnux0ppKPXDyNvgIf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"White ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_8.csv
# Processing batch 9 of 38...
# [{"track_name":"Friends?","track_uri":"spotify:track:0mPNvq9LgQs0GKrSdGIfdH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"No Promises","track_uri":"spotify:track:61h8BQARx7z8M6cdZnVdJ1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Undefeated (feat. 21 Savage)","track_uri":"spotify:track:3rvKAT40Q513rnm4uk0vpN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ya Ho","track_uri":"spotify:track:6b5ohuS1WD7oXESsNWBLzY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Deadcrush - Spike Stent Mix","track_uri":"spotify:track:1Agpg7Y6QxP4HLabHSLR9o","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Atlantic City","track_uri":"spotify:track:4JwjzS9WFkWlpzGCwh82fn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Come Together","track_uri":"spotify:track:6PHYSs95mKzXPoFej25il3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"iLi [Produced by TroyBoi) - Bonus Track","track_uri":"spotify:track:7vhcIX3RUUKJVdt3fpaz2W","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Better Watch What You Sayin","track_uri":"spotify:track:5cZqJCZbztAXFTeUlMsoYN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Make It Nasty","track_uri":"spotify:track:7qXEugMg02cTu1uAaiCsZy","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Party Like A Rock Star (Remix) feat. Chamillionaire & Lil Wayne - Remix","track_uri":"spotify:track:6zGZZcHFFiBPENYCO0xyFc","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Raindrops Keep Fallin' On My Head - Butch Cassidy/Soundtrack Version","track_uri":"spotify:track:1KkwByi6c9dFFmUTcgMODw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Trump","track_uri":"spotify:track:4pxtKmfLPjkmZ223Isu07I","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Gucci Snakes","track_uri":"spotify:track:2nnDjYwhCBBWFectcycARL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Flex Season","track_uri":"spotify:track:4syBn76Vr8ANkgCk5n30uX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Skin Tight","track_uri":"spotify:track:1nQB3GM2GCRRzES9q4XjW6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Corduroy - Mexico City 12/10/05","track_uri":"spotify:track:3UzS5Rgale3YgiI6UmvRci","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mudshovel","track_uri":"spotify:track:5gKu5MM4lYl3AxflyuvXSI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Where Is My Mind - Live","track_uri":"spotify:track:3WJdIwSQT574QssgPUobz0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Shades of Gray","track_uri":"spotify:track:33CVbDlfnTJa8Fb78HZMLe","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Somewhere Down in Texas","track_uri":"spotify:track:1kRlt3v0NI6OLhyMkZZAee","previewUrls":[],"error":"No preview URLs found"},{"track_name":"A Lot To Ask","track_uri":"spotify:track:6XJJ579dHw1qzmKVnBRoGI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"These Tears","track_uri":"spotify:track:48ZV7ZwmmTXU0kA19kIx3k","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Nobody Haunts Me Like You","track_uri":"spotify:track:58siaUSnBZRgHMBUBprDwO","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stick Around","track_uri":"spotify:track:7Dw3JHnv8edzQVnLzONtbJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wicked Twisted Road (Reprise)","track_uri":"spotify:track:0pHu4oucLEyB1lfbxeVKFB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Only That Real (feat. 2 Chainz & Sage The Gemini)","track_uri":"spotify:track:3rTn6YFzpFCN4sxNuF4qtk","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Feel It","track_uri":"spotify:track:7xy4zWufOPUI6RDG0l4nZL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Paris - Subsurface Remix","track_uri":"spotify:track:0PMh1On2M3UhdVEJEBS ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_9.csv
# Processing batch 10 of 38...
# [{"track_name":"About You","track_uri":"spotify:track:0NwrKzIoYpRTgqucyTysye","previewUrls":[],"error":"No preview URLs found"},{"track_name":"3 Years Later","track_uri":"spotify:track:6sc5loEIuJWO7TAnolmFMn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"When Love Calls - Single Version","track_uri":"spotify:track:3t3F0uoY9MoQ7iU8GEOlSU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Two Occasions","track_uri":"spotify:track:0mt80ksFAwPHXyAlArU5Yc","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Keep On Movin' - Feat. Caron Wheeler","track_uri":"spotify:track:37Z7EF33gfoyYgyisevrvo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"We Are One (feat. Frankie Beverly) [2004 - Remastered]","track_uri":"spotify:track:4zEy6bU2BeB4cDDFM62pfd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Abusadora","track_uri":"spotify:track:6aAAASpQdfwAzgT9NPTwEa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"One Night In Bangkok","track_uri":"spotify:track:6vl4ug7vOEyXJGmtnRz5s2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sip My Arizona","track_uri":"spotify:track:6Kpd1qQHHk13aRbDscu4gV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Window Glass (Interlude)","track_uri":"spotify:track:42zrkADx44ctIv7GpZaQSi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hard Carry (하드캐리)","track_uri":"spotify:track:71HIlyWqVtSpyW8dmbtjsf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Just Right","track_uri":"spotify:track:65tfKRivlasyJ2i5uLxTl8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"4 O'clock (Piano Arrangement)","track_uri":"spotify:track:10QD4OdVywdOB3kGJmuNpm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Butterfly (Piano Arrangement)","track_uri":"spotify:track:3tJg3uLJaajtw9whkbRgoU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hot in Here","track_uri":"spotify:track:4MPo5nRV5Z1Mdv82DDCitK","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Fix Me Up","track_uri":"spotify:track:2ZIhalDsTcGgN2xn158JLJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Next to Me - Live from Spotify NYC","track_uri":"spotify:track:4Y1ZvAbetcpZsmedL9uhmR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Back to Boston","track_uri":"spotify:track:7H1nHxmI4hrn4o7IFVaMWe","previewUrls":[],"error":"No preview URLs found"},{"track_name":"This Is the Hunt","track_uri":"spotify:track:2S2ssph6PKx54xn0SLvwbe","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Back Of Da Club","track_uri":"spotify:track:7yer9Ea4gLXgkoLtRzBE7w","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Duffle Bag Boy","track_uri":"spotify:track:09lqmgrszQIGrS5tFlrmhE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Coming Down","track_uri":"spotify:track:2C1igahjiShid8qZ7E2Vq6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"And I Love You So","track_uri":"spotify:track:5IsXkHKbdSjPEFaxg5rewj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sun And Moon - Original London Cast Recording/1989","track_uri":"spotify:track:3rHqyIJ9hxnG1uosWSkxZa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Dream A Little Dream Of Me - The Voice Performance","track_uri":"spotify:track:2rDtRsKNZlGB903kTzvR79","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Jackie Chan","track_uri":"spotify:track:7LosB7f28r3P5BafsmwIMh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"2's Up (feat. Tre Solid)","track_uri":"spotify:track:1iSb0HvypJM5Y9DpAIgH32","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Intro","track_uri":"spotify:track:52rahWphZ8doGURuyL0RS5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Memos","track_uri":"spotify:track:3UWWYrNdyczYGx3E5E3vhi","previewUrls":[],"error":"No pre ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_10.csv
# Processing batch 11 of 38...
# [{"track_name":"Priority","track_uri":"spotify:track:31xOcEuNipF2k4Rmq0WJ0E","previewUrls":[],"error":"No preview URLs found"},{"track_name":"No Hay Nada Mas","track_uri":"spotify:track:6NczWi2A40n2kkTGlZUMAa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pistola","track_uri":"spotify:track:2wCzGkc0TmmNDyu3oC17lr","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Revelations","track_uri":"spotify:track:369LdVD8rOvwc1J888Hrbn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tussle - Feat. Tum Tum","track_uri":"spotify:track:6SokgeTYfvWHOJU3SCBTEa","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Whats Happenin'","track_uri":"spotify:track:6eBcqZ3EJgamC3oFb1K3XD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Revenge (feat. Larry June)","track_uri":"spotify:track:0j8mf5GdMBIPThFODC78ua","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tear Da Roof Off","track_uri":"spotify:track:73zJ6dS5QIVFJxF0y7phJT","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Dresser","track_uri":"spotify:track:51d1jXf0BLoFrp6LurHZMJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Second Eve","track_uri":"spotify:track:1kkVJ4XfE6kKUJ6TszV2wB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Man In The Moon","track_uri":"spotify:track:1eb69cfGd5GCsQ1DcJx9q2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Money","track_uri":"spotify:track:7ImhGKVpzzAZlEXxiEiw3A","previewUrls":[],"error":"No preview URLs found"},{"track_name":"2 Bitches","track_uri":"spotify:track:3peT1g9UCIh1zN1NVwOGZt","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cab Deg","track_uri":"spotify:track:1TquBahz02HCaxj8jy5tTo","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Twin Oaks, Pt. 1","track_uri":"spotify:track:197NhMpSnBzxgC599k9zcm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Easy Muffin","track_uri":"spotify:track:5zYgFOCkYxPbfzq0PYoUR6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"It's True","track_uri":"spotify:track:75UmTIQT5hJguc5HhyQbap","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tiny Cities Made Of Ashes","track_uri":"spotify:track:6dHqtNpPSQajmh85IKItB9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Make You Feel My Love - Live at WXPN","track_uri":"spotify:track:3NYceIpgRH9enVfWVxeLbB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Thursday","track_uri":"spotify:track:12gDVVsfFFgLaLimjNrZNZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Top Hat Bar And Grille","track_uri":"spotify:track:607yjcH65dTBIDtKjIbKI2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Mercy Seat - Live from KCRW","track_uri":"spotify:track:7ig1AKLomvVYqLehmbIlXM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cook up (feat. Young Thug)","track_uri":"spotify:track:7bRmFqEBKSjTRcBpmrbz5S","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Degas Park","track_uri":"spotify:track:0sri8HoWihcZO9Gr31gbmy","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Do What U Want","track_uri":"spotify:track:4MJlgdrGLaayCTPtdn0kII","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sexxx Dreams","track_uri":"spotify:track:7jczFX9ZGyUBtMKAcmUmwI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Perfect Lady - Original Mix","track_uri":"spotify:track:63k5TvVjYK30nqeNun7VTV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Unstoppable - Vinai Remix","track_uri":"spotify:track:4dzGb1o0RHNzE3omFM6PE1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Squeezed Up","track_uri":"spotify:track:3zgDxJKZkaMjq3LtZWggPh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Dripped Out","track_uri":"spotify:track:7gexukrBPXTO9FCtRjkMRL","previewUrls":[],"error":"No preview URLs  ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_11.csv
# Processing batch 12 of 38...
# ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_35.csv
# Processing batch 36 of 38...
# [{"track_name":"Thank You","track_uri":"spotify:track:1yztQEzozNPcnVVVOIkcTb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Don't Go","track_uri":"spotify:track:2cBEDoq1DtLDZ0cfrHh2sA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Synthesizers - Msystem Remix","track_uri":"spotify:track:5Z7twdCbzsMOsjpEOcY3xF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"9 Times out of 10","track_uri":"spotify:track:5gTjur20hnQuX7D2hyp7mF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Black Boy, White Boy","track_uri":"spotify:track:6wmhh4uxX4F9H7gDEfCaeC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Please Forgive Me","track_uri":"spotify:track:2zdMaPQb3WfWBTiysLflIh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bands","track_uri":"spotify:track:6l1nvIcMdDbHIjaBLiu2Dp","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Knotty Head - UK Remix","track_uri":"spotify:track:6LDkQCI4Ryv9FwvJwn4lXM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Song Of The Summer","track_uri":"spotify:track:4ml5byYLNEQkWD245BiPKK","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ice Age","track_uri":"spotify:track:594suifkodzqXMkJlkKRQd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lord Vader Kush II","track_uri":"spotify:track:4Djz7O3kZKbjCpieY9cSXY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"32 Ave Intro","track_uri":"spotify:track:0FH7yQaW5eU7Z9gqoOCcLr","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love You Like I'm Gonna Lose You (Ashley Meghan Personal Trainor Mix)","track_uri":"spotify:track:3IEo4JgPglCM1Vtlmgh7ax","previewUrls":[],"error":"No preview URLs found"},{"track_name":"We Don't Wanna Go","track_uri":"spotify:track:7n2uY0vMmYMXJQQtA4wl11","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cookie Jar","track_uri":"spotify:track:7jE5hACenHaqB8nTBrB0uL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Underneath The Sycamore","track_uri":"spotify:track:38x5Xwz3mkH6iCghORp0gW","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hang On","track_uri":"spotify:track:18MThFxLiQiVHNzqbYTunA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"11:11","track_uri":"spotify:track:6WRcnALbP0YUcND0MtLQoR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Do It With No Hands","track_uri":"spotify:track:2HeBYQEWpMhqduoM3QtRTk","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Day They Make Me Boss","track_uri":"spotify:track:24CzZHV0vnMUMeHjP6Xz7H","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Jovial","track_uri":"spotify:track:2COBMrpsGXEagCGkjp2Siz","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hey Arnold!","track_uri":"spotify:track:2Gi9veF2vWMjOj2g8pSuMC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wings - Shlohmo Remix","track_uri":"spotify:track:3840tCEV3VgTiFHiJsYCT0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Neon","track_uri":"spotify:track:575wNG8uXiF5jjaSdWqdxZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ton Of Love","track_uri":"spotify:track:11HHUytYiDcE2nj3fvBqHb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Just Love Me","track_uri":"spotify:track:2onXZTp7OYgnblrt9eq08I","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bend","track_uri":"spotify:track:11cQFqVRiv5aMIua6E8izR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Proud To Be Here","track_uri":"spotify:track:4xVDPALIbZnB4bvfsbQphg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"My Heaven","track_uri":"spotify:track:0XaWYz6P0HQE1mM3vxmQgr","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Old Love Feels New","track_uri":"spotify:track:00IuYbkpL3bQilWyhhR7aE","previewUrls":[],"error":"No preview  ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_36.csv
# Processing batch 37 of 38...
# [{"track_name":"Last Call","track_uri":"spotify:track:7aDmaHoR45bJ2DQbQex5G5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"More","track_uri":"spotify:track:6V1Us6xbzTCC0EPPgJ69gZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Post (Remix)","track_uri":"spotify:track:2VgbW66hmY9ShMyo2FqtHi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Just The 2 of Us","track_uri":"spotify:track:12cUpsGc7dcfsuTu3QQ88H","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You Name It","track_uri":"spotify:track:0dkYuHtdrKUMi9FzVVoGUg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Real Love","track_uri":"spotify:track:5dbiQ8IldbK0TvEvuWZxBS","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Savage Life","track_uri":"spotify:track:5kYlE3iTzEu1nz12SopxnW","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love Is Wicked","track_uri":"spotify:track:2uBFTrgPZpSLOEoUBd0N5f","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I've Been Loving You Too Long","track_uri":"spotify:track:5QlriozFJTGucROHILK4Fb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Flowers - Live at SXSW 2015","track_uri":"spotify:track:6qRkyd3Z0QrCMMkr9km0Nu","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Love You Truly","track_uri":"spotify:track:6PfUy37wVZfXsh0TE8QJJ9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Afterglow","track_uri":"spotify:track:1EsiDLSQG6yPf4CJ5mxRoN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Drop Girl","track_uri":"spotify:track:4mfl8akhVprr93o1ALep21","previewUrls":[],"error":"No preview URLs found"},{"track_name":"A Fuego Contigo","track_uri":"spotify:track:5HvGeJ9lqXDEpwJegY0Nbv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"No Aguantan Presionpa","track_uri":"spotify:track:4Oe2YENgoxpi3qN7rq2qCy","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ponte Tu Chaleco - Secreto El Biberon","track_uri":"spotify:track:0SxZFHdTnklHQIuld5e7U6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Deme Hilo","track_uri":"spotify:track:3O41dIkyTGmzOQdlB1LLLR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pa Que Tu Me Saluda (feat. Ft Chimbala & El Mayor)","track_uri":"spotify:track:11dahvU36lU7s1eyptHX3Z","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Con los Pie","track_uri":"spotify:track:4mWNkcdcplUIdtgnnBvz0k","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Te Prendo","track_uri":"spotify:track:13Z58yRg3ePgcPCm31u7Xi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Great Balls of Fire","track_uri":"spotify:track:6LivLb2QdgYkSDvN1QVTT8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Givenchy","track_uri":"spotify:track:69PHZDs3vVsnTpTjBOLwYX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"25 Lighters","track_uri":"spotify:track:2sZHd8Wl9lmUhgVwsEr8e6","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cali Girl","track_uri":"spotify:track:786hWdO2DD09eFbHP98xoG","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Made Me","track_uri":"spotify:track:4H1xAKdRblT37ZdaKY8JRB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"One Spot (Official 2016 X Games Anthem)","track_uri":"spotify:track:38LrAzIsp2KpLfwB6d57xP","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wasting Time","track_uri":"spotify:track:2nTgBOxXQYY0PrmC2GBO57","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Keep On","track_uri":"spotify:track:1YLtWXcHSAqh9n35p7NvVD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm Awesome","track_uri":"spotify:track:1qsoQzhJM3eHiF6EFjajZL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"There For You","track_uri":"spotify:track:2AaFh40HT4EymcrfPM7OYN","previewUrls":[],"error":"No preview URLs fou ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_37.csv
# Processing batch 38 of 38...
# [{"track_name":"Clash","track_uri":"spotify:track:0xQy3jp0Rm5Hm0KSbn0BhF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Juice","track_uri":"spotify:track:0WbEdG7nmUyfMKc2YeUBkZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bang","track_uri":"spotify:track:0iwBzxumvbQpykz9kZaEe0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Do Wrong (feat. T-Pain)","track_uri":"spotify:track:04IkWhV5BS3uQxBnNyvb3J","previewUrls":[],"error":"No preview URLs found"},{"track_name":"What If I Kissed You","track_uri":"spotify:track:5oGqJnjSythpdNILDvhEQ3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Crazy for You","track_uri":"spotify:track:0C8uzNntWXQEk8daUSX1oi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Crazy for You - Acoustic","track_uri":"spotify:track:4w9CC4gU49LJzUJDBja6lG","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Everything Without You","track_uri":"spotify:track:6Q8gDPV58pgVN01k916duV","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Role In Creation","track_uri":"spotify:track:6vELYOd6iplCRF2E9s1jkZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Two Stars","track_uri":"spotify:track:0d8vi0ocHIOBiGwhphc1GC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Something - Deconstructed Studio","track_uri":"spotify:track:3359RYhB4jeXz7MowEzE1y","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Kiss Me When I'm Down","track_uri":"spotify:track:26UNTnle7FCmIBkvhVovU8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Are the Good Times Really Over","track_uri":"spotify:track:6Ab1YylmjNmnCZUjr2jT5r","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Jack Daniels","track_uri":"spotify:track:0EsozsJjBFWTGXcfQHU7iQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I'm Gettin' Stoned","track_uri":"spotify:track:1xmlUIXOY0Qci8z0hKv9mD","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Good Times","track_uri":"spotify:track:75RPKgHnThND15kzi03dQl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stung - Rickyxsan Remix","track_uri":"spotify:track:0tMG1mB0JWFtxcifwCCGoR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"11fortySeVn - starRo Remix","track_uri":"spotify:track:2a3O9iEeoQl4bjxGZKX0Af","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hello","track_uri":"spotify:track:1P0ClfdFqaW06atXEMSujJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Designer","track_uri":"spotify:track:5Yv6gocuoZWtf2616H0Hql","previewUrls":[],"error":"No preview URLs found"},{"track_name":"4:00AM","track_uri":"spotify:track:094bq4xBXVbpjNE11kj7Er","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wider Than The Sky","track_uri":"spotify:track:2GZKJ5eb6ey2QKwItopxhQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Budapest - Live from Spotify Stockholm","track_uri":"spotify:track:4HqU80xAozomP0XtgxAu6w","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Put Your Records On - The Voice Performance","track_uri":"spotify:track:0lenKifFLckocR0ydjqIBU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"We Got Us","track_uri":"spotify:track:7kDmuS9vUMDkn7vLr7VJQG","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Better","track_uri":"spotify:track:0ttFKNTcl3DacnwhVfeLAh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Battery Acid","track_uri":"spotify:track:5edZsNwvMSW1T7RTJ8514l","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Street Walker","track_uri":"spotify:track:6iXxw41daSAuyuQgGVkBtQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Valerie - '68 Version","track_uri":"spotify:track:7Lxt392wmXBuWahE55fFAU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Guns Out","track_uri":"spotify:track:6VRCatCERw2gLKkZa50ZXt","prev ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/preview_batches_Xav/batch_38.csv
# Merged file saved to preview_batches_Xav/merged_file(1).csv
# Deleted preview_batches_Xav/batch_8.csv
# Deleted preview_batches_Xav/batch_11.csv
# Deleted preview_batches_Xav/batch_38.csv
# Deleted preview_batches_Xav/batch_10.csv
# Deleted preview_batches_Xav/batch_9.csv
# Deleted preview_batches_Xav/batch_12.csv
# Deleted preview_batches_Xav/batch_13.csv
# Deleted preview_batches_Xav/batch_17.csv
# Deleted preview_batches_Xav/batch_16.csv
# Deleted preview_batches_Xav/batch_28.csv
# Deleted preview_batches_Xav/batch_14.csv
# Deleted preview_batches_Xav/batch_15.csv
# Deleted preview_batches_Xav/batch_29.csv
# Deleted preview_batches_Xav/batch_1.csv
# Deleted preview_batches_Xav/batch_30.csv
# Deleted preview_batches_Xav/batch_24.csv
# Deleted preview_batches_Xav/batch_18.csv
# Deleted preview_batches_Xav/batch_19.csv
# Deleted preview_batches_Xav/batch_25.csv
# Deleted preview_batches_Xav/batch_31.csv
# Deleted preview_batches_Xav/batch_2.csv
# Deleted preview_batches_Xav/batch_27.csv
# Deleted preview_batches_Xav/batch_33.csv
# Deleted preview_batches_Xav/batch_32.csv
# Deleted preview_batches_Xav/batch_26.csv
# Deleted preview_batches_Xav/batch_3.csv
# Deleted preview_batches_Xav/batch_7.csv
# Deleted preview_batches_Xav/batch_22.csv
# Deleted preview_batches_Xav/batch_36.csv
# Deleted preview_batches_Xav/batch_37.csv
# Deleted preview_batches_Xav/batch_23.csv
# Deleted preview_batches_Xav/batch_6.csv
# Deleted preview_batches_Xav/batch_4.csv
# Deleted preview_batches_Xav/batch_35.csv
# Deleted preview_batches_Xav/batch_21.csv
# Deleted preview_batches_Xav/batch_20.csv
# Deleted preview_batches_Xav/batch_34.csv
# Deleted preview_batches_Xav/batch_5.csv
