# %% [markdown]
# Extract Preview URL

# %%
import subprocess
import json
import time
import pandas as pd
import math
import os
import re
import glob

def get_spotify_previews_batch(df_batch):
    data_json = df_batch.to_json(orient="records")
    result = subprocess.run(
        ["node", "spotify_preview.js"],
        input=data_json,
        stdout=subprocess.PIPE,   # Capture stdout explicitly
        stderr=subprocess.STDOUT,  # Merge stderr into stdout
        text=True,
        encoding='utf-8'
    )
    # Print all output so any warnings or messages are visible
    print(result.stdout)
    try:
        return json.loads(result.stdout)
    except json.JSONDecodeError:
        raise ValueError(f"Invalid JSON output: {result.stdout}")

def get_last_processed_batch(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        return 0
    batch_files = [f for f in os.listdir(directory) if f.startswith("batch_") and f.endswith(".csv")]
    batch_numbers = []
    for filename in batch_files:
        match = re.search(r"batch_(\d+)\.csv", filename)
        if match:
            batch_numbers.append(int(match.group(1)))
    return max(batch_numbers, default=0)

def get_new_merged_filepath(directory, base_name='merged_file.csv'):
    merged_filepath = os.path.join(directory, base_name)
    if not os.path.exists(merged_filepath):
        return merged_filepath
    else:
        i = 1
        new_name = f"merged_file({i}).csv"
        new_filepath = os.path.join(directory, new_name)
        while os.path.exists(new_filepath):
            i += 1
            new_name = f"merged_file({i}).csv"
            new_filepath = os.path.join(directory, new_name)
        return new_filepath

def merge_initial_batches(directory):
    """
    Merge any existing batch CSV files (those starting with "batch_") from the given directory.
    Save the merged result (using a new filename if necessary) and delete these batch files.
    """
    csv_files = glob.glob(os.path.join(directory, 'batch_*.csv'))
    if not csv_files:
        print(f"No batch CSV files found in {directory} during initial merge.")
        return pd.DataFrame()
    dfs = [pd.read_csv(file) for file in csv_files]
    merged = pd.concat(dfs, ignore_index=True)
    merged = merged.sort_values(by=['previewUrl'], ascending=False)\
                   .drop_duplicates(subset=['track_uri'], keep='first')
    merged_filepath = get_new_merged_filepath(directory)
    merged.to_csv(merged_filepath, index=False)
    print(f"Initial merged file saved to {merged_filepath}")
    # Delete the batch files
    for file in csv_files:
        try:
            os.remove(file)
            print(f"Deleted batch file: {file}")
        except Exception as e:
            print(f"Could not delete {file}: {e}")
    return merged

def get_spotify_previews_in_batches(dataframe, batch_size=50, delay=2, output_dir=""):
    if not output_dir:
        output_dir = os.getcwd()
    last_batch = get_last_processed_batch(output_dir)
    print(f"Resuming from batch {last_batch + 1} in directory: {output_dir}...")
    dataframe = dataframe.iloc[last_batch * batch_size:]
    num_songs = len(dataframe)
    total_batches = math.ceil(num_songs / batch_size)
    for i in range(0, num_songs, batch_size):
        batch_df = dataframe.iloc[i:i+batch_size]
        batch_index = last_batch + (i // batch_size) + 1
        print(f"Processing batch {batch_index} of {total_batches + last_batch}...")
        batch_results = get_spotify_previews_batch(batch_df)
        batch_data = []
        for entry in batch_results:
            if entry is None:
                continue
            track_name = entry.get("track_name")
            track_uri = entry.get("track_uri")
            preview_url = None
            if "error" not in entry or not entry.get("error"):
                preview_urls = entry.get("previewUrls", [])
                preview_url = preview_urls[0] if preview_urls else None
            batch_data.append({
                "track_name": track_name,
                "track_uri": track_uri,
                "previewUrl": preview_url
            })
        batch_df_results = pd.DataFrame(batch_data)
        csv_filename = f"batch_{batch_index}.csv"
        batch_filepath = os.path.join(output_dir, csv_filename)
        batch_df_results.to_csv(batch_filepath, index=False)
        print(f"Batch saved to {batch_filepath}")
        if i + batch_size < num_songs:
            time.sleep(delay)

def final_merge(directory, combined_df):
    """
    Merge any new batch CSV files in the directory with the combined_df (which includes
    original Parquet data and any initial merged batch data). Then, delete the batch files
    and save the final merged DataFrame to a new CSV file.
    """
    csv_files = glob.glob(os.path.join(directory, 'batch_*.csv'))
    if csv_files:
        new_batches = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)
        for file in csv_files:
            try:
                os.remove(file)
                print(f"Deleted batch file: {file}")
            except Exception as e:
                print(f"Could not delete {file}: {e}")
        combined_df = pd.concat([combined_df, new_batches], ignore_index=True)
    combined_df = combined_df.sort_values(by=['previewUrl'], ascending=False)\
                             .drop_duplicates(subset=['track_uri'], keep='first')
    merged_filepath = get_new_merged_filepath(directory)
    combined_df.to_csv(merged_filepath, index=False)
    print(f"Final merged file saved to {merged_filepath}")
    return combined_df

if __name__ == "__main__":
    # Ask user for the directory where batch CSVs and merged files are saved.
    output_dir = input("Enter the directory where batch CSVs are saved (default: current working directory): ").strip()
    if not output_dir:
        output_dir = os.getcwd()

    # === INITIAL MERGE OF EXISTING BATCH FILES ===
    print("Performing initial merge and cleanup (if any batch files exist)...")
    initial_merged = merge_initial_batches(output_dir)

    # === LOAD & COMBINE ORIGINAL DATA FROM PARQUET ===
    # Prompt user for the exact Parquet file path
    parquet_path = input("Enter the full path to the Parquet file: ").strip()
    if not os.path.isfile(parquet_path):
        raise ValueError(f"Error: The file does not exist at {parquet_path}")
    try:
        df_parquet = pd.read_parquet(parquet_path)
        print("Parquet file loaded successfully!")
    except Exception as e:
        raise ValueError(f"Error reading Parquet file: {e}")
    
    # Ensure the 'previewUrl' column exists
    if 'previewUrl' not in df_parquet.columns:
        df_parquet['previewUrl'] = None
    df_parquet = df_parquet[['track_name', 'track_uri', 'previewUrl']]
    
    # Load any previously merged files (merged_file*.csv)
    merged_files = glob.glob(os.path.join(output_dir, "merged_file*.csv"))
    if merged_files:
        merged_dfs = [pd.read_csv(f) for f in merged_files]
        merged_existing = pd.concat(merged_dfs, ignore_index=True)
        print(f"Loaded {len(merged_existing)} tracks from existing merged files.")
    else:
        merged_existing = pd.DataFrame()

    # Combine the Parquet data with any merged data and initial merged batch data
    combined_df = df_parquet.copy()
    if not merged_existing.empty:
        combined_df = pd.concat([combined_df, merged_existing], ignore_index=True)
    if not initial_merged.empty:
        combined_df = pd.concat([combined_df, initial_merged], ignore_index=True)
    
    # Deduplicate so that records with a valid previewUrl are prioritized
    combined_df = combined_df.sort_values(by=['previewUrl'], ascending=False)\
                             .drop_duplicates(subset=['track_uri'], keep='first')
    
    # Identify processed tracks (those with a valid previewUrl)
    processed_track_uris = combined_df[~combined_df['previewUrl'].isna()]['track_uri'].unique()
    # Filter the Parquet data for tracks that still need preview extraction
    df_to_process = df_parquet[~df_parquet['track_uri'].isin(processed_track_uris)][['track_name', 'track_uri']]
    print(f"Found {len(processed_track_uris)} processed tracks. {len(df_to_process)} tracks remain to be processed.")
    
    # === BATCH PROCESS THE REMAINING TRACKS ===
    get_spotify_previews_in_batches(df_to_process, output_dir=output_dir)
    
    # === FINAL MERGE: COMBINE NEW BATCH FILES WITH THE COMBINED DATA ===
    print("Final merging and cleanup of batch CSV files...")
    final_df = final_merge(output_dir, combined_df)
# Out:
# Performing initial merge and cleanup (if any batch files exist)...
# No batch CSV files found in /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl during initial merge.
# Parquet file loaded successfully!
# Loaded 50447 tracks from existing merged files.
# Found 47605 processed tracks. 2842 tracks remain to be processed.
# Resuming from batch 1 in directory: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl...
# Processing batch 1 of 57...
# [{"track_name":"Back to Me","track_uri":"spotify:track:7MIesTteOBlxjwyE2jMHzw","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Am Done","track_uri":"spotify:track:5lkUNK4YsRB0MYSZ3uzf4W","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Freight Train","track_uri":"spotify:track:3u4sWzzdgKjwdbI0AqTo5m","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Levitate","track_uri":"spotify:track:4xXdaVNU0nWTzcxyVCQsq9","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Say Goodbye - Instrumental","track_uri":"spotify:track:4EVwh71EkJMR5E0UO3EBnl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Face Down A-- Up","track_uri":"spotify:track:3d8SY4HTGZyRtjXOiAb2TT","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sippin Tea in Yo Hood","track_uri":"spotify:track:6KmKcGu5NktXMsZejB9tDN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Porque Es Tan Cruel El Amor","track_uri":"spotify:track:14Osyrs4kYXhH928UVP0ku","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Te Dejo en Libertad","track_uri":"spotify:track:4ZfQP7MvCYi0ElUy3F3HWC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Come My Way (Fetty Wap and Drake Fitness Version Dance remix)","track_uri":"spotify:track:1sZTHBQGg05nNaOad7BqvJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Drugs","track_uri":"spotify:track:5ED296qfp2OjnG1D3kapr2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Trippin'","track_uri":"spotify:track:6VRBKz4Q0IeIZ5J1sohofZ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"1night","track_uri":"spotify:track:1t0KIAY5Toad5H9m1wdlNj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bleed","track_uri":"spotify:track:5l3h1KsMOmMrlwExnizw9U","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sexy Biest - Gui Boratto Remix","track_uri":"spotify:track:2wv2tHn5ylLZ2LfaGCRbcd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Music Sounds Better With You","track_uri":"spotify:track:6BitZqwsfaxVhoq3LE0vMt","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Nightcall - Isaac Tichauer Remix","track_uri":"spotify:track:2LGmPimgB9EgkxKwS5aMCR","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Don't Do Me Like That - Mudcrutch Version","track_uri":"spotify:track:4LcLMJdyKM3wSFIelwkE8S","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Long Cool Woman (In a Black Dress)","track_uri":"spotify:track:3MKeaMa8qTsIQQLoxYdrri","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Walk It Out","track_uri":"spotify:track:0fl6bGMxC5IzSvwYNHYkQj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Boyz n' da Hood","track_uri":"spotify:track:0Ta4s1LOhazQN0RFoGGheQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hey My Man","track_uri":"spotify:track:2TuboYawL4pvkbZPop1Ir5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Love Yourself","track_uri":"spotify:track:46omOkLp16BOCKvQrr8WS0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Take Me Home Country Roads - Instrumental Mix","track_uri":"spotify:track:0lXSTWW7g6GuyuQafQTbKc","previewUrls":[],"error":"No preview URLs found"},{"track_name":"7 Years","track_uri":"spotify:track:3gcXUOm0cLM8drOeJLeKil","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Pillowtalk","track_uri":"spotify:track:2NeaasHaRPjND2rCNFfGCm","previewUrls":[],"error":"No preview URLs found"},{"track_name":"She Will Be Loved - Instrumental Mix","track_uri":"spotify:track:7AGV15ypBTxPtCI68OHSjp","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Haven't Met You Yet - Instrumental Mix","track_uri":"spotify:track:2kbxSQGs7ijs25ymfPVGMp","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cold Water","track_uri":"spotify:track:1cgoi1LPcMRCoVaQtHMgSl","previewUrls":[],"error":"No  ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_1.csv
# Processing batch 2 of 57...
# [{"track_name":"Smoking With Her","track_uri":"spotify:track:0XEwPPRE4rMykJodSJBZP2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ever Be - Bethel Music Version","track_uri":"spotify:track:1qVIMl6dJrZuOfjM73rpmb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Conquered It All","track_uri":"spotify:track:668NpfnQkrSFrM254IGuxY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You Are Holy","track_uri":"spotify:track:0elbfOSyUpcN6SQBsQfEWY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Give You My Heart","track_uri":"spotify:track:265jQJiEpdUVjN40Eo7yaH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Fall in Love","track_uri":"spotify:track:19ZBxGTZuDyV4QoqWe4MoF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"In the Mirror","track_uri":"spotify:track:4WywzuZVYhzBVt4Y8pcNCg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Kingdom Come","track_uri":"spotify:track:1DONFJDk4zkcuwFFYLkkEX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Gone in the Morning","track_uri":"spotify:track:1HLCCelCvYCdifURy9nHqQ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Warrior of Love","track_uri":"spotify:track:6bQREqXNykgoz8Uj0WI6hU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"One Drop - Live at the Santa Barbara County Bowl","track_uri":"spotify:track:1b2qX5B5jktQjHrgewwzDT","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Is This Love - Live at the Santa Barbara County Bowl","track_uri":"spotify:track:7Cfl36b2vAav8o2BzEnrgx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stir It Up - Live at the Santa Barbara County Bowl","track_uri":"spotify:track:1jatm2gOrwrgroFE2cHv59","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Gotta Know","track_uri":"spotify:track:4joHr5HzPDVPqeY2MrAtyh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Corpse Party","track_uri":"spotify:track:76pVl5b5i2ypU3LvnEk1dN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hang With Me","track_uri":"spotify:track:5Ks6XBugC8yanyf8bq7FN4","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Damned","track_uri":"spotify:track:3R5ITCdoejoRBBaoKJyGP2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lullaby Of A Deadman","track_uri":"spotify:track:128zElW4z27JtpfRKPkJwF","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The One","track_uri":"spotify:track:0cFaIwY73zCzTvGiBZECJj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Best Coco","track_uri":"spotify:track:79qSZKTMA60a6DY4vsLtMJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Momma Found My Stash","track_uri":"spotify:track:41X8q4MnzIdbHUaYXND6kU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"La Dah","track_uri":"spotify:track:6CA8JXlc5Qb3eJlAuA2J8D","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Crew","track_uri":"spotify:track:17VpjHj5228NIjVFEN32vx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sorry - Remix","track_uri":"spotify:track:3domOjy1H7QfFueOwfudHN","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cheating and Lying Blues","track_uri":"spotify:track:5LckHR0v3AFqH5ppz5i5pC","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Jealous Sun","track_uri":"spotify:track:70wMwfp8wAqaxip65R8Hkf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Very Last Day","track_uri":"spotify:track:76Fc9ApTagfE0DFLFdnMj1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Be With You","track_uri":"spotify:track:0x2TTX7yTdiL5u2Nc11fms","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Gtfo My Room (feat. Andrew Garcia)","track_uri":"spotify:track:4mxkKwO8or2hIOIIXwNR6y","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Shed a Tear","track_uri":"spot ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_2.csv
# Processing batch 3 of 57...
# [{"track_name":"VUE","track_uri":"spotify:track:1qmZosIwWriTVxwlC7Mgna","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sunshower (H-Track Edition) [feat. Nami Shimada]","track_uri":"spotify:track:3UPzhWNt67PtR2s5R8iSuf","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ain't No Stopping Us Now - Unreleased Version","track_uri":"spotify:track:79UEK0XYemip32SdLdAegB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"La La La","track_uri":"spotify:track:0oEZE99ptV35lV4Z4D8Mxz","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Lon-dubh (Blackbird)","track_uri":"spotify:track:1sc8OpWIym00YoQ1sDFGGe","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Super Going","track_uri":"spotify:track:6RSKPYN02ZG8eIM4gTQFX1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Riddle Me","track_uri":"spotify:track:4vm8JENdLoUNAmeIS8hT2y","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Guards","track_uri":"spotify:track:6iLt99PySEBKWUqZqGGboJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Nikki Benz","track_uri":"spotify:track:3SZrwUncxYooMT5vQtaEzH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Over Do It","track_uri":"spotify:track:7BBZpBJhIDvMgL71BIJ9de","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Foriegn","track_uri":"spotify:track:01ZuCdByBXGfhwjIPT6Be8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Street Wars","track_uri":"spotify:track:0gaI20HgHbh1tcLLQrCQMX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ying Ying","track_uri":"spotify:track:6qh5N9ESq92jXx7lMhHOYc","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Secure the Bag (feat. Lil Skrt)","track_uri":"spotify:track:5SnNJxlWcZ3caaTCMU828D","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Don't Even Know (feat. Lil West)","track_uri":"spotify:track:2ayzSoZcnjwUEOZMviyPxA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Stevie Wonder","track_uri":"spotify:track:5DFRvslBRkr8UABn7XRd89","previewUrls":[],"error":"No preview URLs found"},{"track_name":"In Too Deep (feat. 12am)","track_uri":"spotify:track:3svOEjbJsNwNC8q0LyTXT7","previewUrls":[],"error":"No preview URLs found"},{"track_name":"All the Time (feat. Tory Lanez)","track_uri":"spotify:track:5O1BmeDgEcFRPgTIjFQoKB","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Kareem","track_uri":"spotify:track:03kwrTKNVdJdBqF1W4BW8G","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Light Poles","track_uri":"spotify:track:3KYWWf6QjVsP4dihic7SIU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Follow Me - Commentary Bonus Version","track_uri":"spotify:track:1P7N0XyMp9QJdmXU1QTTGT","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Need You Right Now (feat. Mike Tompkins)","track_uri":"spotify:track:3iftD7fIFcjnh24O2NfvLI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Angel (feat. Parker Polhill & Bibiane Z) [ACOUSTIC MIX] - Acoustic","track_uri":"spotify:track:2mS84tPeBH6n89lv0YC5Pd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"My Youth","track_uri":"spotify:track:1jTIFJAsURP8E7mStl0UoJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Drunk & High","track_uri":"spotify:track:5MLY3pTwlK7yQSIpa24uMA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"April","track_uri":"spotify:track:3aan6nsSYVaFgkEsLYdcLh","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Man of the Year","track_uri":"spotify:track:1EaQFSDNX8N8wNYMSfI5ku","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Swim","track_uri":"spotify:track:7z09S5QppFENnGSQohw0yU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Small Town","track_uri":"spotify:track:67zaEKHTrCc5q5vVLuQc5D","previewUrls":[],"error":"No preview URLs found"},{"track_name":"You Make Me New","tra ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_3.csv
# Processing batch 4 of 57...
# [{"track_name":"Time - from Sons of Anarchy","track_uri":"spotify:track:2SGSPbEGyOSPn7gDgJSEFA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Passenger - from Sons of Anarchy","track_uri":"spotify:track:2vsPBXRfMoTW06P5gnC0EJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Charlie's Van","track_uri":"spotify:track:7xf7piUXb0sQKZkhjFibfb","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Good Love","track_uri":"spotify:track:1dO4NneiOepeYZEnyItTHl","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tomorrow","track_uri":"spotify:track:6AhZylBFvgZnSkofJB7USd","previewUrls":[],"error":"No preview URLs found"},{"track_name":"500 Balazos","track_uri":"spotify:track:75GOVivyqCHpQvZcpiAmum","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Revolving Door - Explicit Album Version","track_uri":"spotify:track:08IzI8UGfNzpnjCpaIOvX1","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Letting Go","track_uri":"spotify:track:2btg4iOzT6UHb31fIoXf6M","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Duces","track_uri":"spotify:track:6Qaf4NboLy7r5Tg7YH4SWi","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Irene Bajo La Cama","track_uri":"spotify:track:3xugwjePZWdLz1G5FJIScG","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Coyita","track_uri":"spotify:track:016vA5iOfrn9LdFWpoIYr3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"The Night (Monday Night Raw Theme)","track_uri":"spotify:track:1xmhkbGrFy9JH98ulHCjFg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Philadelphia Eagles Roll with It (Philadelphia Eagles Fight Song)","track_uri":"spotify:track:6eulRFOvfjjgzzLbPIl6kq","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Reckless","track_uri":"spotify:track:3ZRFSYOrkTc0cRRVUgEXi5","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Table for One","track_uri":"spotify:track:15XPhl0ydVXEortrJPVfGJ","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Yea yea","track_uri":"spotify:track:2HXvKaOtmtnoAxpXqsoqsg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Waterbed","track_uri":"spotify:track:0au6MtgsnsW0kvP0Hbr14v","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Hoto (Remix)","track_uri":"spotify:track:5aRPAbu7iIqzjtXf5HEp0Q","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Thinking out Loud / I'm Not the Only One","track_uri":"spotify:track:1XgUi3BaLQtHProeEdn8bP","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"New World","track_uri":"spotify:track:0ttgiyLkAkxK4rJaLxW3GU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ponte bonita","track_uri":"spotify:track:6syHpGdmvBH6D1CJWj5OCM","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Una Lady Como Tú","track_uri":"spotify:track:4LPlYozO3CIfzU1yCwrpyq","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Para Toda la Vida","track_uri":"spotify:track:1fQLPLnthmD36h189qoXpf","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Quiero Volver","track_uri":"spotify:track:7Eqw2iYcuguMOa812vY4YG","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Shape of You - Remix","track_uri":"spotify:track:6TFpUKLo3hg5gccjwHn8gk","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Origins - Original Mix","track_uri":"spotify:track:3vKhuwZbUAby6rCGEOIXXB","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Soothe Your Pain (Produced By Sinima)","track_uri":"spotify:track:0qDwtfdwpCuhZpB2wNYie1","error":"Failed to fetch preview URLs: Request failed with status code 504","preview ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_4.csv
# Processing batch 5 of 57...
# [{"track_name":"Tobacoo Road","track_uri":"spotify:track:0klFDkkbIL42JsUBg3mUMy","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Night (Was Stealing from the Sun)","track_uri":"spotify:track:4Pl1verUWI5YfATNXoJBhT","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Just In Time","track_uri":"spotify:track:3pChI7tTMViq4kPklW3EJ4","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Central Two-O-Nine","track_uri":"spotify:track:1YgEQJhPVlEjsIvWqVy1P6","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Act Nice and Gentle - Stereo;2014 Remastered Version","track_uri":"spotify:track:4pDar1O7z4Jwon7G8oheTQ","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I Know After Laughter","track_uri":"spotify:track:6yflXzAPml7kzdFHDxjjx5","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Lousy Connection","track_uri":"spotify:track:5pDrHGMPYS6gCsvTB9CX0D","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I'm Broke","track_uri":"spotify:track:2oEILXuW4dgsX3kfX8Umx9","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Shadow Dancing","track_uri":"spotify:track:5GawlskQVseKCWIVWLDare","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Park Hill","track_uri":"spotify:track:1KcmmmY0bKLRswrn0HjbaF","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Run to Me - starRo Remix","track_uri":"spotify:track:4AYF4fq03B6vCndKgnC5BE","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"White Man","track_uri":"spotify:track:3ZPOizpNFO7Ruzxoax7PoV","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Lord Have Mercy","track_uri":"spotify:track:4tTQPeGi69CqZ4FZe5dKoz","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Blowin Money Fast (BMF)","track_uri":"spotify:track:7cLBXjtw27RKHoIplG0FRl","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Reaching","track_uri":"spotify:track:2EH2xP6p6EwoLVSXLVtXAH","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Thief of Hearts","track_uri":"spotify:track:3V5xrcKZwDQehwXn4Izk2A","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Tulsa Time","track_uri":"spotify:track:6qiyBVkWoHT1sFoGUQg7KO","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Stop Calling Us Horrorcore.","track_uri":"spotify:track:1TYLHf1oDFHbinHv1bUtih","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Kill a Dream","track_uri":"spotify:track:4gZurouXM8BJIOm9wlqTwP","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Make a Move","track_uri":"spotify:track:3KOnQS7RepjHmeuZkpd0VV","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Bette Davis Eyes - Rerecorded","track_uri":"spotify:track:5Ous5CT0aTtQFIExWJD371","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"One Dance - Remix","track_uri":"spotify:track:1XPdSxXOXURyiyl0bqKzbe","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Armor4Sync","track_uri": ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_5.csv
# Processing batch 6 of 57...
# [{"track_name":"I'll Stay","track_uri":"spotify:track:6wKwF5HWKJNarmBs3rV8UE","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Walk On Water","track_uri":"spotify:track:5oZo6a7h7k3FJXJ4Vcwqxn","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Behind Blue Eyes - Live","track_uri":"spotify:track:6URa0fC3z52pMzBsiN6eBC","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Slow Down - Radio Edit","track_uri":"spotify:track:1cV9bE8rTZswnQMpFNkx83","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Vanity - Live From Spotify NYC","track_uri":"spotify:track:5XRETvv8UQMxXIVQ8VyeyM","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"October","track_uri":"spotify:track:0E7L1SJOkqCEcWeMNCXseG","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Expectations","track_uri":"spotify:track:4xTvbmA8s7LkxYYTJrJR5s","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"TV Dinners","track_uri":"spotify:track:7v2zh28vgnzvXB990fKMC9","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Cookie Cutter Life","track_uri":"spotify:track:6zfRfoS51KerpgJyGfGJM2","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Kill Tonight","track_uri":"spotify:track:3dNZkLdv2AcUD78cvXRV3c","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Wheels","track_uri":"spotify:track:3swhiq5F7Q3VR6NmQQ2DGG","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Ball On You","track_uri":"spotify:track:19njg7KGU1C83RtT9rcBgF","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Right Here Right Now","track_uri":"spotify:track:2QaPKd4I3QXtvA315RUgiU","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"On Like That","track_uri":"spotify:track:4aP3EYcYqBMMSCSiynK0Li","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Bad Bitches (feat. Rick Ross)","track_uri":"spotify:track:4CGTQ3VdtqHQtzBthmiTHc","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Chihiro (Audiobot Remix)","track_uri":"spotify:track:0k4wUsXmLkP2nM62c7m3ig","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"A Beautiful Mind","track_uri":"spotify:track:0oKqd3mKeKECvEe779A4bB","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Deck The Halls","track_uri":"spotify:track:2orCRTEroDiBAd0Hmpfm7q","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Joy to the World Medley","track_uri":"spotify:track:7eyu6JeojMzZq6jUMSCLXJ","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Carol Of The Bells; Deck The Halls","track_uri":"spotify:track:1N2Vk2qIvTV1g1YVGDRAbH","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Rudolph the Red Nose Rheindeer - Re-Recorded","track_uri":"spotify:track:0PkjYyG4iTjzZFMX8MmoUZ","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Silver Bells","track_uri":"spotify:track:0et9powwNknglOt7hpaW0X","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"We Will Rock You -  ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_6.csv
# Processing batch 7 of 57...
# [{"track_name":"You're In My Head","track_uri":"spotify:track:7hmwy6cSH0x4H8HMVCG3gr","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Married In the Morning","track_uri":"spotify:track:6Qmq2h45lwHCfBVrzVFE87","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Silhouettes (Casio Version)","track_uri":"spotify:track:4IHY8b4jvoZjA2hmImI1XM","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Wallflower","track_uri":"spotify:track:6torqNCgDJOL52u89qmGC0","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Second Guessing Games (Casio Version)","track_uri":"spotify:track:5nbsa2w1lS9O94a9yL0iG8","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Fill My Cup","track_uri":"spotify:track:6wNZWnw5RDDLeSjfWKYyx2","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Daddy","track_uri":"spotify:track:4so07yUlAFAzSQhwbKJDLo","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Tomorrow Will Be Better","track_uri":"spotify:track:1LQ67SkphXipb5KtfuLdku","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Monster in My Bed","track_uri":"spotify:track:6g166fQWQauyW3toIhEaU8","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Garden (feat. Aaron Purdy)","track_uri":"spotify:track:2ItSB39flZ8tHUcaF51a0i","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Bark at the Moon","track_uri":"spotify:track:6zDRnKj33dJIX7KcqOb9Ex","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Amnesiac","track_uri":"spotify:track:7IW8My8QhjJBX6gxHh4oaU","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Sometimes You Gotta Die","track_uri":"spotify:track:7fxUxSJqcyW8xgvtYjlgA7","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Peligrosamente","track_uri":"spotify:track:5Xk2RTYNSatBHpDe18DTq7","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Una Explicación","track_uri":"spotify:track:3uPx13iI2EzZrjc4tfGrFN","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Desaparecido","track_uri":"spotify:track:4PFZqEDyCYfm6qZlskshoc","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Muchas Gracias","track_uri":"spotify:track:0hMrhXemQsyYON48v8k21H","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Porque Sin Ti \"Pensando en Ti\"","track_uri":"spotify:track:1uGy7tqg3hLiKAoQdNLXD0","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Waiting for Nothing","track_uri":"spotify:track:6IqZiNzCpTnYchJaooqGEV","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Polanski","track_uri":"spotify:track:3SrNeY9GdSDst4ZY808pzg","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Wet and cold","track_uri":"spotify:track:6gmWWq8EQ5358r2Jqrk2aP","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Sunrise","track_uri":"spotify:track:3pOXVoaXf9yc9JSBTyX4Ud","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"The Message","track_uri":"spotify:track:4XWRJ ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_7.csv
# Processing batch 8 of 57...
# [{"track_name":"Cash Me Outside","track_uri":"spotify:track:5sSfTjuy58gaGmXgJgvTXL","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Crowns - Remix","track_uri":"spotify:track:08wiCIT1lHzfaBdDaXdWiM","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Tired of Waiting","track_uri":"spotify:track:0dpJ9NP9bEaf1pp12iHP2z","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Slauson2boston","track_uri":"spotify:track:0fFqFSda2OqBv0YtLJVNLX","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Rub It In","track_uri":"spotify:track:6q014fQ3SqLy180KPuCTG1","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Bajen Pa Aca (feat. Anuel Aa)","track_uri":"spotify:track:2vOX1wa76We1xLqUKU2lC7","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Me Enamoré","track_uri":"spotify:track:2dwJY8s7TqZcXC73p0J1fT","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Pewdiepie Go Die (Pewdiepie Diss Track)","track_uri":"spotify:track:3CB1QZrXjMrFtt1wrY9aQK","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Nothing Here but Love - Twice As Nice Remix","track_uri":"spotify:track:6SOgB8kcbzNeU7uHLB8Zrl","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Now","track_uri":"spotify:track:5RHmORxFV5i02uaMKwFj8V","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Missing U","track_uri":"spotify:track:7jtJ9vYNznVyQClE4AbRxb","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I See Fire","track_uri":"spotify:track:4YfQolcrxO4ZzyNvwyeoRf","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Passionfruit","track_uri":"spotify:track:0CVvtfZjapoI7rg1fhgMwi","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Jealous","track_uri":"spotify:track:72UnikVahbg2B24xxrlJJN","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Crazy 4 U","track_uri":"spotify:track:0jGBYhyTD4QU2dguYN7L7X","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Hold On","track_uri":"spotify:track:1RZpFzNlRNXkz4NEBLyNkG","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Spooky Scary Skeletons - Remix","track_uri":"spotify:track:6pwWIKw85UcUz83dhQ7GEe","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Magic - Live at Today FM","track_uri":"spotify:track:0YjgRKsrlzAV6jjGrH70KD","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Moreno De Revista (feat. Magreidy)","track_uri":"spotify:track:32DGRPv4Q7ExeOPOnhbv22","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Follar Es Bueno","track_uri":"spotify:track:2rxDKAjzOEQZB58OiwS9bc","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"To Lo Gogo","track_uri":"spotify:track:413DzML78wQBEuykUZYtne","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Twist Of Fate","track_uri":"spotify:track:533BzrB9TWzWH27T9Ra7Um","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Twenty Years On","track_uri":"spotify:track:2xRo ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_8.csv
# Processing batch 9 of 57...
# [{"track_name":"Linda Linda","track_uri":"spotify:track:0AGNJ20HD2zWlx9DQHoj87","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Fantastic Cat","track_uri":"spotify:track:1B0Thx3eY7d6DCbiwiYHCK","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Thank You For Sending Me An Angel [Version] (45 Version)","track_uri":"spotify:track:4AzlLdmSFFcxTxVaiDcJB1","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Dreams of Caves","track_uri":"spotify:track:28sWJVpuCf4hzSJWEpAc2Z","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Heaven Sent (feat. J-Louis)","track_uri":"spotify:track:5YwuJotHN5IwK5Brb25nwe","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Low Key","track_uri":"spotify:track:4zeEbXXsPyU5GhHK3vUFNy","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Migraine - Live From SXSW","track_uri":"spotify:track:1TsxL6nhuECZssktA8qcoI","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"We Own The Night (feat. Luciana) [Radio Edit]","track_uri":"spotify:track:1tygoO6VWdXZM79ilOu2lc","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Into Your Mercy","track_uri":"spotify:track:3tskr8oLQMK7ixpp2WSCnL","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Good Times","track_uri":"spotify:track:1hOjrE0Ef7wRdpcS9h6wQ4","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Dynasty","track_uri":"spotify:track:73koutfp2oY0tUOrddkO9c","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Motown","track_uri":"spotify:track:75RH2jIiPqow6s3b5rTU9p","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Scum","track_uri":"spotify:track:4UVPrKCM6y6IytA1ah4FhC","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Electric Rainbow","track_uri":"spotify:track:6nSZJos3zVhXspQeYtcxXY","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Get Your Shit Together","track_uri":"spotify:track:7KhO89I3p6LhLsHykQzMUN","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"King Of Yesterday","track_uri":"spotify:track:7zr6XqrP42DVdRqgQUMzPl","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Right To Be Wrong (Live Session (iTunes Exclusive))","track_uri":"spotify:track:042yT5iiGzFTQzVE6CTpey","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Slipping (Soulwax Remix)","track_uri":"spotify:track:1FvOxa6miCnsgNtw2tLYBY","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Summertime","track_uri":"spotify:track:6ZoY4JuMpnTkQTLE8tYP5k","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Tears","track_uri":"spotify:track:2cLWSDO6MdSGwDjyrRCcvR","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"My Band","track_uri":"spotify:track:5peY3taBu88Ls2t7TywcxG","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Us Against The World","track_uri":"spotify:track:2ynFPgrRgKZCz1o4CB7VWA","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Childho ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_9.csv
# Processing batch 10 of 57...
# [{"track_name":"Tales from the Lab (Dirty disco RMX by Axel Bartsch)","track_uri":"spotify:track:46LA36sA98qCxOfKJc9o9N","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"The Elephant - Joseph Capriati Remix","track_uri":"spotify:track:1RNTm68epAsGpdwx8LgZ0Z","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"The Elephant","track_uri":"spotify:track:2PK2xRSaBv8QYXty13Z4Q9","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"The Elephant - Dustin Zahn Remix","track_uri":"spotify:track:26ziKOjbjlprG5Yt2OuSC0","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Time Is Passing - Edit","track_uri":"spotify:track:0Yq9q4rL3DzjO9z8bFXuN4","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Living The Life - ABA Therapy Version Droog DJ Mix","track_uri":"spotify:track:34b0UBP9k2YXaKWj6Wmf4j","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Halfway","track_uri":"spotify:track:2AwBmuQNis3ukhkuFkeSHs","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Until You Come Back Home","track_uri":"spotify:track:1i8RWgY7iDTu7NvEWAvFVV","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Snow White","track_uri":"spotify:track:2oOdqSXzpLEpag77vssdk3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Someday","track_uri":"spotify:track:2cc48sJeBOLqG67e3JHqPn","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Eyes and Lips","track_uri":"spotify:track:2Tx1TGi06GaitSj4t04DIN","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I'm Done","track_uri":"spotify:track:2CuWBMkqfT73oIZkFXi3Go","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Honk (If You're Tonky)","track_uri":"spotify:track:7HleeFQBGp0KRS8ABCKQeE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"GROUP EXERCISE 一起运动","track_uri":"spotify:track:6YiswMlzrexLRG8n2tJxgS","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Leanin","track_uri":"spotify:track:6595GMrHroXuLpqNcJpVXW","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Drive-By","track_uri":"spotify:track:678K16qavpFSLk9eLOMaww","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"''I Love My Choppa''","track_uri":"spotify:track:6Re8IQUzg7tkO6bA0s7lBf","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Flexin on My Ex","track_uri":"spotify:track:1GjJ4gC27fGlSSZsTausK7","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Floating","track_uri":"spotify:track:49mCjhS9LkvEevHCkXi2eD","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I Want To Love You","track_uri":"spotify:track:4wSu50Ez401OFBhX4iR0dx","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Unforgettable (Spanish Remix)","track_uri":"spotify:track:4iFTKFNULHYkZA4N9Oc8JV","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Oooh","track_uri":"spotify:track:1atVMK071XAWd1pUFN47JP","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Letter To My Son","track_uri":"spotify:track:626HZrARglZn5tou9ZaqlR","error":"Failed to fetch preview URLs: Request failed with st ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_10.csv
# Processing batch 11 of 57...
# [{"track_name":"We Ready","track_uri":"spotify:track:0ZNE9ofDouSlU036b5IzIT","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I'm Ballin","track_uri":"spotify:track:7j7T31qvlPU6CGbk1QyDx4","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"King On Set","track_uri":"spotify:track:5To8B1kvvVdIMv1AZ9vJNt","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Go Hard","track_uri":"spotify:track:5JJCOighnvJYDssjJt8wh2","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"King of the Jungle (Club Mix)","track_uri":"spotify:track:01NWptkR2CAmlObmKZ7stH","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Coastline (Goldroom Remix)","track_uri":"spotify:track:5wQ1bLzthXiclOmJQaJhhe","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Rush - Sam Feldt Remix","track_uri":"spotify:track:5BvzO49DsznjvkSYOEJEom","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"No Woman No Cry - Live","track_uri":"spotify:track:1SX2IC1mGA8XnBt5fE3PHz","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Mercy","track_uri":"spotify:track:0FSDyRlOcjUWd6YxrKtoRH","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"London, Tokyo, Paris","track_uri":"spotify:track:048dGlCnEIu5CJiSpLYE8F","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"White Tiger","track_uri":"spotify:track:7uDhRuKGzU717pSjJUZqDV","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"Love Me Like You Do (from 50 Shades of Grey) - A Tribute to Ellie Goulding","track_uri":"spotify:track:6mDMyEyX4rb6CyMN5OSlau","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Jubel - Radio Edit","track_uri":"spotify:track:58VSx2Adlz83g6YVDdJ0zR","error":"Failed to fetch preview URLs: Request failed with status code 504","previewUrls":[]},{"track_name":"You & I","track_uri":"spotify:track:6qd35KUaLaA7XVqJQljn7A","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"One Day (Vandaag) - Ultra Deep House Mix","track_uri":"spotify:track:155xCnQipv8E9vAuimiEUR","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"They Reminisce Over You","track_uri":"spotify:track:2QUCsbC1kPq30qSiSEqRZh","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Shit Iz Real - Buckshot's New Vocals","track_uri":"spotify:track:12120A8H54JoXOSlLtou9g","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Buck Em Down - Remix","track_uri":"spotify:track:1G7KP4vOGAjUDklhT06MOq","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"I'll Take Her","track_uri":"spotify:track:6kHwbzrIm9fZUHQg0WsxOK","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Isnt She Lovely (feat. Chris Fatouros, Madeline Perrone & Juan Martinez)","track_uri":"spotify:track:53stoW9UOVd6bD0XpA1U1O","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Day 72 - The Show Goes On","track_uri":"spotify:track:7Lkt4elmG0kALjYZWOtoxU","error":"Failed to fetch preview URLs: Request failed with status code 503","previewUrls":[]},{"track_name":"Call It Whatever","track_uri":"spotify:track:2uNsKVLn18P8lq9gGUSraT","error":"Failed to fetch preview URLs: Request failed with ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_11.csv
# Processing batch 12 of 57...
# ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_56.csv
# Processing batch 57 of 57...
# [{"track_name":"Killin' Mind","track_uri":"spotify:track:2pOBqtWjBkvQRsdctH4WxE","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Waves (feat. Marque)","track_uri":"spotify:track:3J1VIMXySKkmpUjQWHELRx","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Playin Around","track_uri":"spotify:track:237tdkBYoEmHKctPrkuykn","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Wavy","track_uri":"spotify:track:6T5CSMGjvilCWL4Gu7Zg3P","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Throw Back","track_uri":"spotify:track:6lH2jjIgjnvlZfpBOfzWJv","previewUrls":[],"error":"No preview URLs found"},{"track_name":"I Can Tell You","track_uri":"spotify:track:2hJCueQil3amcyZ3jBZ5rX","previewUrls":[],"error":"No preview URLs found"},{"track_name":"ROCKXANN","track_uri":"spotify:track:0e1Jhyt7hcklhIIhSRF5V0","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Glow","track_uri":"spotify:track:05FGACqEQvyvUvm81ITpm8","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cat with the Mac","track_uri":"spotify:track:1W1GwSjDSFSXQFX3R8EG5S","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Splash","track_uri":"spotify:track:0VUorwVMNFjHuDHd049yD3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Sun Rocks","track_uri":"spotify:track:7Lg3D83zmbDRJGYqSkyTfj","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Ruby","track_uri":"spotify:track:3LF72EbdLf8oxZggEkoKVg","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Interlube","track_uri":"spotify:track:0HYQRK6seQb4GkdWWxTViA","previewUrls":[],"error":"No preview URLs found"},{"track_name":"XANXIETY","track_uri":"spotify:track:45EutPcXT47B6whWTxdK8N","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Memories of Ourselves with Each Other","track_uri":"spotify:track:7r5DO1cnSIOajOTx8Wpan3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Gimme Sympathy","track_uri":"spotify:track:29okqwWfb2iDDHPOLi5XHP","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Bromance - Avicii's Arena Radio Edit","track_uri":"spotify:track:6ZbkkRSH8sfudGXgMcBMY3","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Now Or Never - Wolfgang Gartner Edit","track_uri":"spotify:track:22r2X4sfhVaV349CqkzqZ7","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Cry (Just A Little)","track_uri":"spotify:track:2jb5Wg3OTKDfeyLZSbizou","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Embers - Original Mix","track_uri":"spotify:track:2oCH19mkLWRe1C0EU2xUcy","previewUrls":[],"error":"No preview URLs found"},{"track_name":"London - DJ Antoine Vs Mad Mark 2k16 London Bassline Radio Edit","track_uri":"spotify:track:7bSigQy38pg7vnrYeoAbeL","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Symphony No 2 In D Major Op 43, 4th Movement: Finale (Allgro Moderato)","track_uri":"spotify:track:2LkxRgu28kiVyumGrp6qA2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"An American in Paris","track_uri":"spotify:track:2qTBt72BWi12GEzvZpz8gI","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Mayor Que Yo","track_uri":"spotify:track:0H26e1PgtkQ2aTRZEKWOOO","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Tu Baby Me Llama [Europe Remix]","track_uri":"spotify:track:5roDVTDfmuxpDIBfMcB3HY","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Blackbird","track_uri":"spotify:track:1yyoXvegrF9Q0PIL0eLPDU","previewUrls":[],"error":"No preview URLs found"},{"track_name":"What's on Your Mind","track_uri":"spotify:track:2xigRSqrfMevIpAZffB9wp","previewUrls":[],"error":"No preview URLs found"},{"track_name":"FIZZ","track_uri":"spotify:track:2wdsZhLcjZDTzfbabIN5f2","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Interlude MB Theme","track_uri":"spotify:track:3YewrarMNEcQyPydnmt4xk","previewUrls":[],"error":"No preview URLs found"},{"track_name":"Interlude MB The ...
# Batch saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_57.csv
# Final merging and cleanup of batch CSV files...
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_8.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_11.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_39.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_38.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_10.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_9.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_12.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_13.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_17.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_16.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_28.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_14.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_15.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_29.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_48.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_49.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_53.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_47.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_46.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_52.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_44.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_50.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_51.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_45.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_41.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_55.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_54.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_40.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_56.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_42.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_43.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_57.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_1.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_30.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_24.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_18.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_19.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_25.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_31.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_2.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_27.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_33.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_32.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_26.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_3.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_7.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_22.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_36.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_37.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_23.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_6.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_4.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_35.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_21.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_20.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_34.csv
# Deleted batch file: /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/batch_5.csv
# Final merged file saved to /Users/xavierhua/Documents/GitHub/bt4222grp9/phase2_feature_engineering/spotify_previewurl_extraction/Ungchan_previewurl/merged_file(1).csv
