# %%
import os
from dotenv import load_dotenv
import lyricsgenius
import re
import pandas as pd
import time

# %%
dotenv_path = "../.env"  
load_dotenv(dotenv_path=dotenv_path)

token = os.getenv("GENIUS_CLIENT_ACCESS")
genius = lyricsgenius.Genius(token)
genius.verbose = False 
genius.remove_section_headers = True
genius.timeout=10

# %%
def getLyrics(artist, song):
    start_time = time.time()
    time.sleep(1)  
    try:
        result = genius.search_song(song, artist)
        if result:
            # Extract lyrics after the word 'Lyrics' (if present)
            lyrics = result.lyrics
            lyrics_start = lyrics.lower().find("lyrics")
            if lyrics_start != -1:
                lyrics = lyrics[lyrics_start + len("Lyrics"):].strip()
            
            # Print the time taken for the request
            elapsed_time = time.time() - start_time
            print(f"Time taken for '{song}' by {artist}: {elapsed_time:.2f} seconds")
            
            return lyrics
        else:
            print(f"Lyrics not found for {song} by {artist}")
            return "Lyrics not found"
    except Exception as e:
        print(f"Error fetching lyrics for {song} by {artist}: {e}")
        return f"Error: {e}"

# %%
file_path = "../spotify_tracks_50.csv"  
df = pd.read_csv(file_path)

# Ensure column names match your CSV
if "artist_name" not in df.columns or "track_name" not in df.columns:
    raise ValueError("CSV must have 'artist' and 'song' columns!")

# Fetch lyrics for each row
df["lyrics"] = df.apply(lambda row: getLyrics(row["artist_name"], row["track_name"]), axis=1)
print(df.head(5))
df.to_csv("spotify_tracks_50_with_lyrics.csv", index=False)
# Out:
# Time taken for 'Side To Side' by Ariana Grande: 4.91 seconds
# Time taken for 'Fight Song' by Rachel Platten: 4.43 seconds
# Time taken for 'Heathens' by Twenty One Pilots: 7.57 seconds
# Time taken for 'Sit Still, Look Pretty' by Daya: 3.94 seconds
# Time taken for 'My House' by Flo Rida: 4.35 seconds
# Time taken for 'Work from Home' by Fifth Harmony: 5.42 seconds
# Time taken for 'Morocco' by Moon Taxi: 3.55 seconds
# Time taken for 'Make Your Mind Up' by Moon Taxi: 3.67 seconds
# Time taken for 'Unstoppable' by Kat Deluna: 3.10 seconds
# Time taken for 'Closer' by The Chainsmokers: 7.50 seconds
# Time taken for 'Road Less Traveled' by Lauren Alaina: 2.67 seconds
# Time taken for 'Me And My Broken Heart' by Rixton: 4.39 seconds
# Time taken for 'Seein' Red' by Dustin Lynch: 3.48 seconds
# Time taken for 'Roses' by The Chainsmokers: 4.46 seconds
# Time taken for 'Ride' by Twenty One Pilots: 5.15 seconds
# Time taken for 'All Time Low' by Jon Bellion: 4.68 seconds
# Time taken for 'Break Your Heart' by Taio Cruz: 4.02 seconds
# Time taken for 'Cheap Thrills' by Sia: 4.47 seconds
# Time taken for 'Put A Label On It' by Ryan Follese: 4.27 seconds
# Time taken for 'No Diggity' by Blackstreet: 6.13 seconds
# Time taken for 'Send My Love (To Your New Lover)' by Adele: 6.70 seconds
# Time taken for 'Red Hot Lights' by Moon Taxi: 4.47 seconds
# Time taken for 'Who's To Say? - Live' by Moon Taxi: 3.36 seconds
# Time taken for 'Year Zero - Live' by Moon Taxi: 3.09 seconds
# Time taken for 'Domino' by Moon Taxi: 3.99 seconds
# Time taken for 'The New Black - Live & Unplugged' by Moon Taxi: 3.99 seconds
# Time taken for 'Suspicious - Live & Unplugged' by Moon Taxi: 4.21 seconds
# Time taken for 'All You Wanted' by Michelle Branch: 4.51 seconds
# Time taken for 'Everywhere' by Michelle Branch: 4.71 seconds
# Time taken for 'Money Maker' by Ludacris: 4.39 seconds
# Time taken for 'Shape of You' by Ed Sheeran: 7.32 seconds
# Time taken for 'Body Like A Back Road' by Sam Hunt: 5.38 seconds
# Time taken for 'Make You Miss Me' by Sam Hunt: 5.11 seconds
# Time taken for 'Break Up In A Small Town' by Sam Hunt: 4.58 seconds
# Time taken for 'Take Your Time' by Sam Hunt: 3.74 seconds
# Time taken for 'All Night' by Dustin Lynch: 3.47 seconds
# Time taken for 'The Way I Talk' by Morgan Wallen: 4.09 seconds
# Time taken for 'Hurricane' by Luke Combs: 4.28 seconds
# Time taken for 'Somethin' I'm Good At' by Brett Eldredge: 3.72 seconds
# Time taken for 'Ride' by SoMo: 4.50 seconds
# Time taken for 'All Star' by Smash Mouth: 11.56 seconds
# Time taken for 'Blue (Da Ba Dee) - Extended Mix' by Eiffel 65: 4.41 seconds
# Time taken for 'All The Small Things' by blink-182: 10.14 seconds
# Time taken for 'That's What I Like' by Bruno Mars: 5.47 seconds
# Time taken for 'Castle on the Hill' by Ed Sheeran: 6.72 seconds
# Time taken for 'No Such Thing as a Broken Heart' by Old Dominion: 4.30 seconds
# Time taken for 'Snapback' by Old Dominion: 4.38 seconds
# Time taken for 'Break Up with Him' by Old Dominion: 3.58 seconds
# Time taken for 'Song for Another Time' by Old Dominion: 4.69 seconds
# Time taken for 'Half Empty' by Old Dominion: 4.23 seconds
#                               track_uri              album_name  \
# 0  spotify:track:4pLwZjInHj3SimIyN9SnOz         Dangerous Woman
# 1  spotify:track:37f4ITSlgPX81ad2EvmVQr                Wildfire
# 2  spotify:track:6i0V12jOa3mr6uu4WYhUBr                Heathens
# 3  spotify:track:2DpCdPMg1BADE4HDnxt3Rd  Sit Still, Look Pretty
# 4  spotify:track:6Knv6wdA0luoMUuuoYi2i1                MY HOUSE
#
#                               album_uri        artist_name  \
# 0  spotify:album:4lVR2fg3DAUQpGVJ6DciHW      Ariana Grande
# 1  spotify:album:0mFDIOqypzHp6Xd0el1hoT     Rachel Platten
# 2  spotify:album:3J8W9AOjQhnBLCX33m3atT  Twenty One Pilots
# 3  spotify:album:2cE2eOy7alOZHpuelJEV8Q               Daya
# 4  spotify:album:5lkNnHVlnCCCV304t89wOH           Flo Rida
#
#                               artist_uri  duration_ms  pos  \
# 0  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR       226160    0
# 1  spotify:artist:3QLIkT4rD2FMusaqmkepbq       204013    1
# 2  spotify:artist:3YQKmKGau1PzlVlkL1iodx       195920    2
# 3  spotify:artist:6Dd3NScHWwnW6obMFbl1BH       202226    3
# 4  spotify:artist:0jnsk9HBra6NMjO2oANoPY       192190    4
#
#                track_name                                 inside_playlists  \
# 0            Side To Side  [584466 290613 339107 ... 932309 757216 867665]
# 1              Fight Song  [584466 290613 540271 ... 535890 217688  26462]
# 2                Heathens  [584466 290613 339107 ... 349806 168239 932309]
# 3  Sit Still, Look Pretty  [584466 414677 809633 ...   6555 349244 395752]
# 4                My House  [584466 290613 968716 ... 257996 349976   6463]
#
#                                               lyrics
# 0  I've been here all night (Ariana)\nI've been h...
# 1  Like a small boat on the ocean\nSending big wa...
# 2  All my friends are heathens, take it slow (In ...
# 3  Could dress up to get love, but guess what?\nI...
# 4  Open up the champagne, pop\nIt's my house, com...
